# %% [markdown]
# # 1. GRU 모델을 사용하여 비트코인 예측하는 프로그램

# %% [markdown]
# ## 0-1. test 데이터와 train 데이터를 split() 함수를 이용해 데이터를 섞는 프로그램 , 80%를 학습 데이터셋으로, 20%를 테스트 데이터셋(검증용)   --> 샘플링 편향 때문에 split() 함수 사용  ( 샘플링 편향: 데이터가 한쪽에 몰려있다)

# %% [markdown]
# ### 0-1-1. 데이터불러오기

# %%
# !pip install finance-datareader # FinanceDataReader에서 데이터를 불러오기 위해 FinanceDataReader를 설치하는 과정
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.50-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.27.1)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.50 requests-file-1.5.1

# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from sklearn.model_selection import train_test_split

# 데이터 불러오기
start_date_q = "2018-01-01"
end_date_q = "2023-03-23"
ticker_q = "BTC/KRW"
df_data_q= fdr.DataReader(ticker_q, start_date_q, end_date_q)

# %%
df_data_q.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-01  15047133.0  15046287.0  14026068.0  14548333.0  14548333.0
# 2018-01-02  14514031.0  16400157.0  13990142.0  15918331.0  15918331.0
# 2018-01-03  15914188.0  16565566.0  15788165.0  16172952.0  16172952.0
# 2018-01-04  16247109.0  16707220.0  15433904.0  16552935.0  16552935.0
# 2018-01-05  16423476.0  18802922.0  16131843.0  18510128.0  18510128.0
#
#                     Volume
# Date
# 2018-01-01  10962700800000
# 2018-01-02  17899344238000
# 2018-01-03  17950689456200
# 2018-01-04  23115024576400
# 2018-01-05  25319034814500

# %%
df_data_q.to_csv("bitcoin2.csv", index = False)  # df_bitcoin_q를 csv파일로 저장

# %%
df_q= pd.DataFrame(fdr.DataReader(ticker_q, start_date_q, end_date_q)['Close'])

# %%
df_q.head()
# Out:
#                  Close
# Date
# 2018-01-01  14548333.0
# 2018-01-02  15918331.0
# 2018-01-03  16172952.0
# 2018-01-04  16552935.0
# 2018-01-05  18510128.0

# %% [markdown]
# ### 0-1-2. 데이터 전처리

# %%
# 데이터 전처리
scaler_q = MinMaxScaler()
scaled_data_q = scaler_q.fit_transform(df_q)

# minmaxScaler는 스케일을 조정하는 정규화 함수로, 모든 데이터가 0과 1사이의 값을 갖도록 해주는 함수이다
                          # 따라서 최댓값은 1로, 최솟값은 0으로 데이터의 범위를 조정해준다. 객체생성함

# %% [markdown]
# ### 0-1-3. train, test 데이터 생성

# %%
train_data_q, test_data_q = train_test_split(scaled_data_q, test_size=0.2, random_state=42)

def create_dataset_q(data_q, look_back_q=60):  #look_back은 몇 개의 과거 데이터를 사용할 것인지를 표현하는 것이다(기본값이 60이다)
    x_q, y_q = [], []  #  for문에서 얻은 모든 입력 데이터(x)와 출력 데이터(y)를 리스트에 추가한다
    for i in range(len(data_q)-look_back_q):
        x_q.append(data_q[i:(i+look_back_q), 0])    # i부터 (i+look_back)까지의 데이터를 하나의 입력 데이터 x_q 로 표현한다.
        y_q.append(data_q[i+look_back_q, 0])   # i+look_back의 데이터를 출력 데이터 y_q 로 표현한다.
    return np.array(x_q), np.array(y_q)       # 리스트를 numpy 배열로 변환하여 반환

look_back_q = 60
x_train_q, y_train_q = create_dataset_q(train_data_q, look_back_q)
x_test_q, y_test_q = create_dataset_q(test_data_q, look_back_q)

# create_dataset()는 시계열 데이터를 RNN 모델에 입력으로 사용하기 위해 입력 데이터와 출력 데이터로 분리하는 함수이다.
# random_state=42 는 다시 실행한 결과값을 같은 결과값이 나오도록 설정

# %%
# split 함수를 이용해 테스트 데이터와 훈련데이터 나누기
# Split the data into training and testing sets
#train_data_q, test_data_q = train_test_split(scaled_data_q, test_size=0.2, shuffle=False)

# %%
train_data_q
# Out:
# array([[0.06420723],
#        [0.11214408],
#        [0.50869316],
#        ...,
#        [0.09055291],
#        [0.67771506],
#        [0.43075275]])

# %%
test_data_q
# Out:
# array([[0.83266105],
#        [0.07442904],
#        [0.29199195],
#        [0.12839949],
#        [0.01066492],
#        [0.24033272],
#        [0.07910168],
#        [0.0880566 ],
#        [0.10814405],
#        [0.15143675],
#        [0.86300406],
#        [0.13077254],
#        [0.27730232],
#        [0.08244871],
#        [0.0084147 ],
#        [0.30119369],
#        [0.71836666],
#        [0.06003629],
#        [0.00576966],
#        [0.70088407],
#        [0.04724384],
#        [0.08853034],
#        [0.80956695],
#        [0.45689372],
#        [0.06278869],
#        [0.10089005],
#        [0.06898097],
#        [0.62768375],
#        [0.2784853 ],
#        [0.47458923],
#        [0.07594635],
#        [0.10935482],
#        [0.61238544],
#        [0.60874704],
#        [0.0436397 ],
#        [0.45153148],
#        [0.54659823],
#        [0.43799041],
#        [0.11229976],
#        [0.30672507],
#        [0.13865119],
#        [0.02031108],
#        [0.00986246],
#        [0.13717064],
#        [0.66663335],
#        [0.35036883],
#        [0.00987834],
#        [0.61091676],
#        [0.04650949],
#        [0.89305144],
#        [0.67575145],
#        [0.14105152],
#        [0.72354431],
#        [0.04890639],
#        [0.04800086],
#        [0.29144937],
#        [0.30504166],
#        [0.00585014],
#        [0.03626714],
#        [0.60225126],
#        [0.30646808],
#        [0.21310049],
#        [0.06663494],
#        [0.3177008 ],
#        [0.04767063],
#        [0.53547522],
#        [0.32331476],
#        [0.58599959],
#        [0.08451999],
#        [0.65333072],
#        [0.61604909],
#        [0.4282844 ],
#        [0.2968122 ],
#        [0.08983749],
#        [0.22663833],
#        [0.90314044],
#        [0.34527557],
#        [0.09318574],
#        [0.09260639],
#        [0.11870009],
#        [0.34461335],
#        [0.06634541],
#        [0.43272509],
#        [0.25909894],
#        [0.09756616],
#        [0.43668437],
#        [0.01435968],
#        [0.60372743],
#        [0.58909721],
#        [0.03398584],
#        [0.92369907],
#        [0.00956901],
#        [0.33481209],
#        [0.43956545],
#        [0.01296066],
#        [0.0106795 ],
#        [0.13246505],
#        [0.1438531 ],
#        [0.31218191],
#        [0.06196231],
#        [0.02356489],
#        [0.6485676 ],
#        [0.35214224],
#        [0.05083608],
#        [0.1027855 ],
#        [0.12016119],
#        [0.07909155],
#        [0.80402024],
#        [0.4626708 ],
#        [0.0985235 ],
#        [0.07487924],
#        [0.0448865 ],
#        [0.22943608],
#        [0.72536264],
#        [0.28336383],
#        [0.0825475 ],
#        [0.00258898],
#        [0.0075191 ],
#        [0.09691357],
#        [0.51406711],
#        [0.07294042],
#        [0.39461376],
#        [0.28780625],
#        [0.44946466],
#        [0.63139841],
#        [0.11209495],
#        [0.11026123],
#        [0.44809713],
#        [0.08706087],
#        [0.06213708],
#        [0.11730077],
#        [0.66974512],
#        [0.08032113],
#        [0.77463487],
#        [0.04435462],
#        [0.11030185],
#        [0.35769976],
#        [0.03166962],
#        [0.07713735],
#        [0.05407526],
#        [0.42864551],
#        [0.58298329],
#        [0.09714938],
#        [0.04499316],
#        [0.35695641],
#        [0.77666663],
#        [0.22102687],
#        [0.3117073 ],
#        [0.58279133],
#        [0.07756466],
#        [0.72685119],
#        [0.70485032],
#        [0.77956971],
#        [0.06467055],
#        [0.10876055],
#        [0.04449427],
#        [0.1135337 ],
#        [0.00894473],
#        [0.04581738],
#        [0.5677727 ],
#        [0.05237308],
#        [0.00953785],
#        [0.31410277],
#        [0.09649653],
#        [0.05005435],
#        [0.77207756],
#        [0.46237775],
#        [0.31368774],
#        [0.39456538],
#        [0.25072288],
#        [0.10374986],
#        [0.14461243],
#        [0.01012549],
#        [0.67487218],
#        [0.22686197],
#        [0.11491225],
#        [0.47839388],
#        [0.08168654],
#        [0.54825339],
#        [0.09967707],
#        [0.07324719],
#        [0.10117873],
#        [0.89825238],
#        [0.11407742],
#        [0.06510738],
#        [0.2344899 ],
#        [0.00873686],
#        [0.62366375],
#        [0.04106894],
#        [0.43604358],
#        [0.67801963],
#        [0.69897405],
#        [0.03174358],
#        [0.10983412],
#        [0.64533631],
#        [0.11151476],
#        [0.07682525],
#        [0.10274947],
#        [0.06540584],
#        [0.04790394],
#        [0.08924486],
#        [0.69324348],
#        [0.04159199],
#        [0.58698264],
#        [0.07980871],
#        [0.6840828 ],
#        [0.83207618],
#        [0.10724564],
#        [0.10691376],
#        [0.04467196],
#        [0.60051952],
#        [0.11022365],
#        [0.20905235],
#        [0.52850118],
#        [0.66110616],
#        [0.04690342],
#        [0.05072652],
#        [0.0064152 ],
#        [0.04999655],
#        [0.00800324],
#        [0.46079306],
#        [0.00730234],
#        [0.32486553],
#        [0.363605  ],
#        [0.04780741],
#        [0.04791213],
#        [0.63933675],
#        [0.07586758],
#        [0.10562754],
#        [0.084379  ],
#        [0.0043798 ],
#        [0.11604142],
#        [0.31625891],
#        [0.04562122],
#        [0.06720724],
#        [0.46507952],
#        [0.43659226],
#        [0.07059909],
#        [0.08425298],
#        [0.04438241],
#        [0.1032667 ],
#        [0.10914174],
#        [0.40822706],
#        [0.31580327],
#        [0.11046054],
#        [0.06198615],
#        [0.76801956],
#        [0.23544641],
#        [0.13586257],
#        [0.11513573],
#        [0.47758204],
#        [0.09219441],
#        [0.79132493],
#        [0.82219018],
#        [0.32146406],
#        [0.3238386 ],
#        [0.42368516],
#        [0.06629963],
#        [0.22222646],
#        [0.67789958],
#        [0.35255706],
#        [0.66329715],
#        [0.11567003],
#        [0.06008805],
#        [0.13442559],
#        [0.09373786],
#        [0.17810681],
#        [0.13399117],
#        [0.06209558],
#        [0.45234017],
#        [0.01281026],
#        [0.01072421],
#        [0.51390685],
#        [0.63004734],
#        [0.6880886 ],
#        [0.55813815],
#        [0.08382727],
#        [0.11332652],
#        [0.0486845 ],
#        [0.0992319 ],
#        [0.00948089],
#        [0.2292814 ],
#        [0.12636836],
#        [0.63197992],
#        [0.83747776],
#        [0.62234387],
#        [0.10726254],
#        [0.08584293],
#        [0.30602671],
#        [0.22729794],
#        [0.04848115],
#        [0.12331406],
#        [0.67102086],
#        [0.04462327],
#        [0.31689614],
#        [0.03071294],
#        [0.32486194],
#        [0.32327469],
#        [0.45209203],
#        [0.5865398 ],
#        [0.30502852],
#        [0.60059341],
#        [0.59770737],
#        [0.08706479],
#        [0.00546805],
#        [0.03125027],
#        [0.11281822],
#        [0.79577821],
#        [0.52511428],
#        [0.09693817],
#        [0.23907879],
#        [0.04415675],
#        [0.06980021],
#        [0.51347269],
#        [0.36949985],
#        [0.88237839],
#        [0.04794984],
#        [0.68872128],
#        [0.08098168],
#        [0.0294485 ],
#        [0.51763204],
#        [0.09531081],
#        [0.01196499],
#        [0.65479867],
#        [0.00687793],
#        [0.11717819],
#        [0.03764513],
#        [0.00927364],
#        [0.61503945],
#        [0.13109027],
#        [0.00509579],
#        [0.66970222],
#        [0.57194294],
#        [0.54350448],
#        [0.62986803],
#        [0.10409769],
#        [0.03090151],
#        [0.10713436],
#        [0.23373868],
#        [0.15487667],
#        [0.04538161],
#        [0.63264606],
#        [0.05352543],
#        [0.30046431],
#        [0.08565452],
#        [0.09192355],
#        [0.81031823],
#        [0.31355973],
#        [0.09526149],
#        [0.09513378],
#        [0.09287988],
#        [0.44516441],
#        [0.0609334 ],
#        [0.07925499],
#        [0.11479814],
#        [0.0439527 ],
#        [0.10101131],
#        [0.7817371 ],
#        [0.75651919],
#        [0.11043494],
#        [0.01445461],
#        [0.24064601],
#        [0.31783426],
#        [0.51151652],
#        [0.00274261],
#        [0.43245201],
#        [0.04538953],
#        [0.13331393],
#        [0.11574093],
#        [0.30236211],
#        [0.60884901],
#        [0.10281144],
#        [0.3476801 ],
#        [0.0494577 ],
#        [0.78622978],
#        [0.04295678],
#        [0.13225712],
#        [0.76829351],
#        [0.2402967 ],
#        [0.06421581],
#        [0.13915123],
#        [0.05741309]])

# %%
x_train_q
# Out:
# array([[0.06420723, 0.11214408, 0.50869316, ..., 0.0538935 , 0.00822543,
#         0.01075279],
#        [0.11214408, 0.50869316, 0.24150708, ..., 0.00822543, 0.01075279,
#         0.59947607],
#        [0.50869316, 0.24150708, 0.00362466, ..., 0.01075279, 0.59947607,
#         0.06233135],
#        ...,
#        [0.045903  , 0.0611267 , 0.11236242, ..., 0.35910225, 0.48659966,
#         0.42161313],
#        [0.0611267 , 0.11236242, 0.08559104, ..., 0.48659966, 0.42161313,
#         0.09055291],
#        [0.11236242, 0.08559104, 0.29067238, ..., 0.42161313, 0.09055291,
#         0.67771506]])

# %%
 y_train_q
# Out:
# array([0.59947607, 0.06233135, 0.11086821, ..., 0.09055291, 0.67771506,
#        0.43075275])

# %%
x_test_q
# Out:
# array([[0.83266105, 0.07442904, 0.29199195, ..., 0.00585014, 0.03626714,
#         0.60225126],
#        0.0043798 , 0.11604142, 0.31625891, 0.04562122, 0.06720724,
#        0.46507952, 0.43659226, 0.07059909, 0.08425298, 0.04438241,
#        0.1032667 , 0.10914174, 0.40822706, 0.31580327, 0.11046054,
#        0.06198615, 0.76801956, 0.23544641, 0.13586257, 0.11513573,
#        0.47758204, 0.09219441, 0.79132493, 0.82219018, 0.32146406,
#        0.3238386 , 0.42368516, 0.06629963, 0.22222646, 0.67789958,
#        0.35255706, 0.66329715, 0.11567003, 0.06008805, 0.13442559,
#        0.09373786, 0.17810681, 0.13399117, 0.06209558, 0.45234017,
#        0.01281026, 0.01072421, 0.51390685, 0.63004734, 0.6880886 ,
#        0.55813815, 0.08382727, 0.11332652, 0.0486845 , 0.0992319 ,
#        0.00948089, 0.2292814 , 0.12636836, 0.63197992, 0.83747776,
#        0.62234387, 0.10726254, 0.08584293, 0.30602671, 0.22729794,
#        0.04848115, 0.12331406, 0.67102086, 0.04462327, 0.31689614,
#        0.03071294, 0.32486194, 0.32327469, 0.45209203, 0.5865398 ,
#        0.30502852, 0.60059341, 0.59770737, 0.08706479, 0.00546805,
#        0.03125027, 0.11281822, 0.79577821, 0.52511428, 0.09693817,
#        0.23907879, 0.04415675, 0.06980021, 0.51347269, 0.36949985,
#        0.88237839, 0.04794984, 0.68872128, 0.08098168, 0.0294485 ,
#        0.51763204, 0.09531081, 0.01196499, 0.65479867, 0.00687793,
#        0.11717819, 0.03764513, 0.00927364, 0.61503945, 0.13109027,
#        0.00509579, 0.66970222, 0.57194294, 0.54350448, 0.62986803,
#        0.10409769, 0.03090151, 0.10713436, 0.23373868, 0.15487667,
#        0.04538161, 0.63264606, 0.05352543, 0.30046431, 0.08565452,
#        0.09192355, 0.81031823, 0.31355973, 0.09526149, 0.09513378,
#        0.09287988, 0.44516441, 0.0609334 , 0.07925499, 0.11479814,
#        0.0439527 , 0.10101131, 0.7817371 , 0.75651919, 0.11043494,
#        0.01445461, 0.24064601, 0.31783426, 0.51151652, 0.00274261,
#        0.43245201, 0.04538953, 0.13331393, 0.11574093, 0.30236211,
#        0.60884901, 0.10281144, 0.3476801 , 0.0494577 , 0.78622978,
#        0.04295678, 0.13225712, 0.76829351, 0.2402967 , 0.06421581,
#        0.13915123, 0.05741309])

# %% [markdown]
# ### 0-1-4. 모델생성

# %%
# 모델 생성
model_q = Sequential()   # 모델의 객체생성
model_q.add(GRU(50, input_shape=(look_back_q, 1)))   #  50=레이어의 출력 차원, input_shape=입력 데이터의 형태를 정의를 의미한다.
                                                  # lock_back=이전 데이터의 갯수만큼 비트코인 가격을 입력으로 받아들이고, 각각의 데이터가 1차원인 것을 의미합니다.

model_q.add(Dense(1))    # Dense 는 완전 연결 레이어(층)를 의미한다. 1은 출력의 차원을 의미

model_q.compile(loss='mean_squared_error', optimizer='adam')   # compile() 함수를 이용하여 모델을 컴파일합니다
                                                             # loss는 손실 함수를 의미한다.
                                                             # mean_squared_error(MSE) 는 전체 에러를 표현하기 위해서 사용하는 식이고 오차의 제곱에 대해 평균을 취한 것이다.(수치가 작을 수록 원본과의 오차가 적은 것이다)
                                                             # optimizer는  최적화 알고리즘을 정의하는 부분이다. adam(아담) 은 모멘텀+ AdaGrad(아다그라드) 을 합친 것이다

# 완전 연결 레이어 : 한 레이어의 모든 뉴런이 그 다음 레이어의 모든 뉴런과 연결된 상태이다.
# 모멘텀 : 기울기 방향으로 힘을 받아 물체가 가속된다는 물리법칙을 적용한것이다.
# AdaGrad : 학습을 진행하면서 학습률을 점차 줄여가는 방법이다.

# %% [markdown]
# ### 0-1-5. 모델학습

# %%
# 모델 학습
model_q.fit(x_train_q, y_train_q , epochs=100, batch_size=64, verbose=2)

# x_train_q : 학습데이터의 입력값   , y_train_q : 학습데이터의 출력값이다.

# 에포크 : 훈련 데이터셋에 포함된 모든 데이터들이 한 번씩 모델을 통과한 횟수 또는 전체 학습 데이터셋에 대한 반복 횟수이다
# 에포크가 높을수록 더 많은 반복 학습을 수행하게 되므로 모델이 더 많은 학습을 하게 되어 일반적으로 더 좋은 성능을 낼 수 있습니다

# batch_size(배치크기) : 학습을 수행할 때, 몇 개의 데이터를 한 번에 처리할지를 지정한다, 일반적으로 32,64, 128 숫자를 사용한다

# verbose : 학습 과정 중 출력되는 문구를 설정합니다. 0일 경우 출력하지 않으며, 1일 경우 학습 진행 상황을 출력하고, 2일 경우 학습 결과만 출력한다
# Out:
# Epoch 1/100
# 23/23 - 3s - loss: 0.0816 - 3s/epoch - 120ms/step
# Epoch 2/100
# 23/23 - 1s - loss: 0.0633 - 680ms/epoch - 30ms/step
# Epoch 3/100
# 23/23 - 1s - loss: 0.0623 - 694ms/epoch - 30ms/step
# Epoch 4/100
# 23/23 - 1s - loss: 0.0624 - 706ms/epoch - 31ms/step
# Epoch 5/100
# 23/23 - 1s - loss: 0.0620 - 641ms/epoch - 28ms/step
# Epoch 6/100
# 23/23 - 1s - loss: 0.0620 - 659ms/epoch - 29ms/step
# Epoch 7/100
# 23/23 - 1s - loss: 0.0619 - 665ms/epoch - 29ms/step
# Epoch 8/100
# 23/23 - 1s - loss: 0.0620 - 997ms/epoch - 43ms/step
# Epoch 9/100
# 23/23 - 1s - loss: 0.0621 - 749ms/epoch - 33ms/step
# Epoch 10/100
# 23/23 - 1s - loss: 0.0620 - 890ms/epoch - 39ms/step
# Epoch 11/100
# 23/23 - 2s - loss: 0.0621 - 2s/epoch - 71ms/step
# Epoch 12/100
# 23/23 - 1s - loss: 0.0620 - 1s/epoch - 48ms/step
# Epoch 13/100
# 23/23 - 1s - loss: 0.0618 - 681ms/epoch - 30ms/step
# Epoch 14/100
# 23/23 - 1s - loss: 0.0619 - 654ms/epoch - 28ms/step
# Epoch 15/100
# 23/23 - 1s - loss: 0.0619 - 675ms/epoch - 29ms/step
# Epoch 16/100
# 23/23 - 1s - loss: 0.0618 - 680ms/epoch - 30ms/step
# Epoch 17/100
# 23/23 - 1s - loss: 0.0618 - 686ms/epoch - 30ms/step
# Epoch 18/100
# 23/23 - 1s - loss: 0.0618 - 663ms/epoch - 29ms/step
# Epoch 19/100
# 23/23 - 1s - loss: 0.0619 - 681ms/epoch - 30ms/step
100
# 23/23 - 1s - loss: 0.0617 - 1s/epoch - 60ms/step
# Epoch 86/100
# 23/23 - 1s - loss: 0.0618 - 1s/epoch - 56ms/step
# Epoch 87/100
# 23/23 - 1s - loss: 0.0619 - 1s/epoch - 55ms/step
# Epoch 88/100
# 23/23 - 2s - loss: 0.0617 - 2s/epoch - 68ms/step
# Epoch 89/100
# 23/23 - 1s - loss: 0.0616 - 1s/epoch - 46ms/step
# Epoch 90/100
# 23/23 - 1s - loss: 0.0616 - 1s/epoch - 55ms/step
# Epoch 91/100
# 23/23 - 1s - loss: 0.0617 - 1s/epoch - 46ms/step
# Epoch 92/100
# 23/23 - 1s - loss: 0.0617 - 667ms/epoch - 29ms/step
# Epoch 93/100
# 23/23 - 1s - loss: 0.0615 - 692ms/epoch - 30ms/step
# Epoch 94/100
# 23/23 - 1s - loss: 0.0617 - 680ms/epoch - 30ms/step
# Epoch 95/100
# 23/23 - 1s - loss: 0.0616 - 686ms/epoch - 30ms/step
# Epoch 96/100
# 23/23 - 1s - loss: 0.0617 - 724ms/epoch - 31ms/step
# Epoch 97/100
# 23/23 - 1s - loss: 0.0618 - 677ms/epoch - 29ms/step
# Epoch 98/100
# 23/23 - 1s - loss: 0.0617 - 665ms/epoch - 29ms/step
# Epoch 99/100
# 23/23 - 1s - loss: 0.0616 - 650ms/epoch - 28ms/step
# Epoch 100/100
# 23/23 - 1s - loss: 0.0617 - 673ms/epoch - 29ms/step

# %% [markdown]
# ### 0-1-6. 예측

# %%
# 예측
train_predict_q = model_q.predict(x_train_q)
test_predict_q = model_q.predict(x_test_q)
# Out:
# 46/46 [==============================] - 1s 8ms/step
# 11/11 [==============================] - 0s 8ms/step

# %% [markdown]
# ### 0-1-7. 시각화

# %%
import matplotlib.pyplot as plt
import datetime

# 예측 결과 시각화
train_predict_q = scaler_q.inverse_transform(train_predict_q)  # inverse_transform()함수로 원본값을 복원할수있다.
y_train_q = scaler_q.inverse_transform(y_train_q.reshape(-1,1))
test_predict_q = scaler_q.inverse_transform(test_predict_q)
y_test_q = scaler_q.inverse_transform(y_test_q.reshape(-1,1))

# train 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df_q[look_back_q:len(train_data_q)].index, y_train_q, label='Actual Train Price')
plt.plot(df_q[look_back_q:len(train_data_q)].index, train_predict_q, label='Predicted Train Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# test 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df_q[len(train_data_q)+look_back_q:].index, y_test_q, label='Actual Test Price')
plt.plot(df_q[len(train_data_q)+look_back_q:].index, test_predict_q, label='Predicted Test Price')

# 2031년 1월 1일에 빨간색 세로축을 추가합니다.
target_date = datetime.datetime(2023, 1, 1)
plt.axvline(x=target_date, color='red', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# 예측 결과 시각화
train_predict_q = scaler_q.inverse_transform(train_predict_q)
test_predict_q = scaler_q.inverse_transform(test_predict_q)

plt.plot(df_q[look_back_q:len(train_data_q)].index, df_q[look_back_q:len(train_data_q)].values, label='Actual Train Price')
plt.plot(df_q[len(train_data_q)+look_back_q:].index, df_q[len(train_data_q)+look_back_q:].values, label='Actual Test Price')
plt.plot(df_q[look_back_q:len(train_data_q)].index, train_predict_q, label='Predicted Train Price')
plt.plot(df_q[len(train_data_q)+look_back_q:].index, test_predict_q, label='Predicted Test Price')
plt.xlabel('Date')
plt.ylabel('Price')

plt.legend()
plt.show()



# scaler_q.inverse_transform() : MinMaxScaler() 을 하기전 원래 데이터로 변환하는 함수

# %% [markdown]
# ### 0-1-8. R2(결정계수)를 이용한 정확도

# %%
from sklearn.metrics import r2_score


# Train 데이터의 R2 score
train_r2_q = r2_score(y_train_q, train_predict_q)
print("Train R2 score:", train_r2_q)

# Test 데이터의 R2 score
test_r2_q = r2_score(y_test_q, test_predict_q)
print("Test R2 score:", test_r2_q)
# Out:
# Train R2 score: -1.0176482970400524e+16
# Test R2 score: -9943263376871836.0

# %% [markdown]
# ### 0-19. MSE를 이용한 정확도

# %%
test_mse_q = model_q.evaluate(x_test_q, y_test_q, verbose=0)
print('Test MSE:', test_mse_q)   # 정확도가 6.5% 이다.
# Out:
# Test MSE: 0.06480655819177628

# %% [markdown]
# ##  1- 1. 데이터 불러오기 ( 2018년~ 2022년 데이터 학습 한후 2023년 예측)

# %%
# !pip install finance-datareader # FinanceDataReader에서 데이터를 불러오기 위해 FinanceDataReader를 설치하는 과정
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.50-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.27.1)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.50 requests-file-1.5.1

# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from sklearn.metrics import r2_score

# 데이터 불러오기
start_date = "2018-01-01"
end_date = "2023-12-31"  #22.12.31 원래 데이터
ticker = "BTC/KRW"  # 한국거래소에서 비트코인을 가격 데이터 가져오기
df_data = fdr.DataReader(ticker, start_date, end_date)
df = pd.DataFrame(fdr.DataReader(ticker, start_date, end_date)['Close'])

# %%
df_data.to_csv("bitcoin.csv", index = False)  # df_data을 csv파일로 저장

# %%
len(df)
# Out:
# 1826

# %%
df_data = fdr.DataReader(ticker, start_date, end_date)
df_data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-01  15047133.0  15046287.0  14026068.0  14548333.0  14548333.0
# 2018-01-02  14514031.0  16400157.0  13990142.0  15918331.0  15918331.0
# 2018-01-03  15914188.0  16565566.0  15788165.0  16172952.0  16172952.0
# 2018-01-04  16247109.0  16707220.0  15433904.0  16552935.0  16552935.0
# 2018-01-05  16423476.0  18802922.0  16131843.0  18510128.0  18510128.0
#
#                     Volume
# Date
# 2018-01-01  10962700800000
# 2018-01-02  17899344238000
# 2018-01-03  17950689456200
# 2018-01-04  23115024576400
# 2018-01-05  25319034814500

# %%
df.head()  # 한국거래소에서 데이터 가져오기(df_data 에서 상위 5개만 추출한 결과)
# Out:
#                  Close
# Date
# 2018-01-01  14548333.0
# 2018-01-02  15918331.0
# 2018-01-03  16172952.0
# 2018-01-04  16552935.0
# 2018-01-05  18510128.0

# %%
len(df_data)  # 전체 데이터의 갯수
# Out:
# 1826

# %% [markdown]
# ## 1-2. 데이터 전처리

# %%
# 데이터 전처리
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df) # minmaxScaler는 스케일을 조정하는 정규화 함수로, 모든 데이터가 0과 1사이의 값을 갖도록 해주는 함수이다
                          # 따라서 최댓값은 1로, 최솟값은 0으로 데이터의 범위를 조정해준다. 객체생성함

# %%
scaler
# Out:
# MinMaxScaler()

# %%
scaled_data
# Out:
# array([[0.14048103],
#        [0.15816443],
#        [0.16145098],
#        ...,
#        [0.22350292],
#        [0.22312377],
#        [0.22222646]])

# %%
# train, test 데이터 생성

train_size = int(len(scaled_data) * 0.8)   ## 전체 데이터셋 중 80%를 학습 데이터셋으로, 20%를 테스트 데이터셋(검증용) 으로 사용하기 위해서 0.8을 곱했다
                                          # 모델 학습 시 과적합을 방지하고 일반화 성능을 높이기 위해 사용된다
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

def create_dataset(data, look_back=60): #look_back은 몇 개의 과거 데이터를 사용할 것인지를 표현하는 것이다(기본값이 60이다)
    x, y = [], []        #  for문에서 얻은 모든 입력 데이터(x)와 출력 데이터(y)를 리스트에 추가한다
    for i in range(len(data)-look_back):
        x.append(data[i:(i+look_back), 0])   # i부터 (i+look_back)까지의 데이터를 하나의 입력 데이터 x 로 표현한다.
        y.append(data[i+look_back, 0])       # i+look_back의 데이터를 출력 데이터 y 로 표현한다.
    return np.array(x), np.array(y)         # 리스트를 numpy 배열로 변환하여 반환

# create_dataset()는 시계열 데이터를 RNN 모델에 입력으로 사용하기 위해 입력 데이터와 출력 데이터로 분리하는 함수이다.

look_back = 60
x_train, y_train = create_dataset(train_data, look_back)
x_test, y_test = create_dataset(test_data, look_back)

# %%
train_data
# Out:
# array([[0.14048103],
#        [0.15816443],
#        [0.16145098],
#        ...,
#        [0.68289049],
#        [0.6629012 ],
#        [0.67771506]])

# %% [markdown]
# ## 1-3. GRU 모델 생성

# %%
# 모델 생성
model = Sequential()   # 모델의 객체생성
model.add(GRU(50, input_shape=(look_back, 1)))   #  50=레이어의 출력 차원, input_shape=입력 데이터의 형태를 정의를 의미한다.
                                                  # lock_back=이전 데이터의 갯수만큼 비트코인 가격을 입력으로 받아들이고, 각각의 데이터가 1차원인 것을 의미합니다.

model.add(Dense(1))   # Dense 는 완전 연결 레이어(층)를 의미한다. 1은 출력의 차원을 의미

model.compile(loss='mean_squared_error', optimizer='adam')  # compile() 함수를 이용하여 모델을 컴파일합니다
                                                             # loss는 손실 함수를 의미한다.
                                                             # mean_squared_error(MSE) 는 전체 에러를 표현하기 위해서 사용하는 식이고 오차의 제곱에 대해 평균을 취한 것이다.(수치가 작을 수록 원본과의 오차가 적은 것이다)
                                                             # optimizer는  최적화 알고리즘을 정의하는 부분이다. adam(아담) 은 모멘텀+ AdaGrad(아다그라드) 을 합친 것이다

# 완전 연결 레이어 : 한 레이어의 모든 뉴런이 그 다음 레이어의 모든 뉴런과 연결된 상태이다.

# 모멘텀 : 기울기 방향으로 힘을 받아 물체가 가속된다는 물리법칙을 적용한것이다.
# AdaGrad : 학습을 진행하면서 학습률을 점차 줄여가는 방법이다.

# %%
model

# %% [markdown]
# ## 1-4. GRU 모델 학습

# %%
# 모델 학습
model.fit(x_train, y_train, epochs=100, batch_size=64, verbose=2)

# x_train : 학습데이터의 입력값   , y_train : 학습데이터의 출력값이다.

# 에포크 : 훈련 데이터셋에 포함된 모든 데이터들이 한 번씩 모델을 통과한 횟수 또는 전체 학습 데이터셋에 대한 반복 횟수이다
# 에포크가 높을수록 더 많은 반복 학습을 수행하게 되므로 모델이 더 많은 학습을 하게 되어 일반적으로 더 좋은 성능을 낼 수 있습니다

# batch_size(배치크기) : 학습을 수행할 때, 몇 개의 데이터를 한 번에 처리할지를 지정한다, 일반적으로 32,64, 128 숫자를 사용한다

# verbose : 학습 과정 중 출력되는 문구를 설정합니다. 0일 경우 출력하지 않으며, 1일 경우 학습 진행 상황을 출력하고, 2일 경우 학습 결과만 출력한다
# Out:
# Epoch 1/100
# 24/24 - 3s - loss: 0.0605 - 3s/epoch - 112ms/step
# Epoch 2/100
# 24/24 - 1s - loss: 0.0061 - 691ms/epoch - 29ms/step
# Epoch 3/100
# 24/24 - 1s - loss: 0.0010 - 773ms/epoch - 32ms/step
# Epoch 4/100
# 24/24 - 1s - loss: 6.4298e-04 - 995ms/epoch - 41ms/step
# Epoch 5/100
# 24/24 - 1s - loss: 5.6455e-04 - 919ms/epoch - 38ms/step
# Epoch 6/100
# 24/24 - 1s - loss: 5.3940e-04 - 690ms/epoch - 29ms/step
# Epoch 7/100
# 24/24 - 1s - loss: 5.1170e-04 - 707ms/epoch - 29ms/step
# Epoch 8/100
# 24/24 - 1s - loss: 4.8790e-04 - 695ms/epoch - 29ms/step
# Epoch 9/100
# 24/24 - 1s - loss: 4.8281e-04 - 724ms/epoch - 30ms/step
# Epoch 10/100
# 24/24 - 1s - loss: 4.6196e-04 - 709ms/epoch - 30ms/step
# Epoch 11/100
# 24/24 - 1s - loss: 4.3933e-04 - 715ms/epoch - 30ms/step
# Epoch 12/100
# 24/24 - 1s - loss: 4.3253e-04 - 686ms/epoch - 29ms/step
# Epoch 13/100
# 24/24 - 1s - loss: 4.1083e-04 - 691ms/epoch - 29ms/step
# Epoch 14/100
# 24/24 - 1s - loss: 4.0353e-04 - 698ms/epoch - 29ms/step
# Epoch 15/100
# 24/24 - 1s - loss: 3.9395e-04 - 733ms/epoch - 31ms/step
# Epoch 16/100
# 24/24 - 1s - loss: 3.8136e-04 - 1s/epoch - 44ms/step
# Epoch 17/100
# 24/24 - 1s - loss: 3.7858e-04 - 899ms/epoch - 37ms/step
# Epoch 18/100
# 24/24 - 1s - loss: 3.6975e-04 - 1s/epoch - 52ms/step
# Epoch 19/100
# 24/24 - 2s - loss: 3.6556e-04 - 2s/epoch - 76ms/step
# Epoch 20/100
# 24/24 - 1s - loss: 3.5440e-04 - 678ms/epoch - 28ms/step
# Epoch 21/100
# 24/24 - 1s - loss: 3.5382e-04 - 709ms/epoch - 30ms/step
# Epoch 22/100
# 24/24 - 1s - loss: 3.5494e-04 - 699ms/epoch - 29ms/step
# Epoch 23/100
# 24/24 - 1s - loss: 3.3760e-04 - 982ms/epoch - 41ms/step
# Epoch 24/100
# 24/24 - 2s - loss: 3.3395e-04 - 2s/epoch - 66ms/step
# Epoch 25/100
# 24/24 - 1s - loss: 3.2936e-04 - 986ms/epoch - 41ms/step
# Epoch 26/100
# 24/24 - 1s - loss: 3.1836e-04 - 1s/epoch - 51ms/step
# Epoch 27/100
# 24/24 - 1s - loss: 3.3068e-04 - 707ms/epoch - 29ms/step
# Epoch 28/100
# 24/24 - 1s - loss: 3.2099e-04 - 710ms/epoch - 30ms/step
# Epoch 29/100
# 24/24 - 1s - loss: 3.1306e-04 - 682ms/epoch - 28ms/step
# Epoch 30/100
# 24/24 - 1s - loss: 3.0999e-04 - 1s/epoch - 46ms/step
# Epoch 31/100
# 24/24 - 2s - loss: 3.0710e-04 - 2s/epoch - 71ms/step
# Epoch 32/100
# 24/24 - 2s - loss: 3.1242e-04 - 2s/epoch - 67ms/step
# Epoch 33/100
# 24/24 - 1s - loss: 3.1087e-04 - 989ms/epoch - 41ms/step
# Epoch 34/100
# 24/24 - 1s - loss: 3.0432e-04 - 721ms/epoch - 30ms/step
# Epoch 35/100
# 24/24 - 1s - loss: 3.0250e-04 - 685ms/epoch - 29ms/step
# Epoch 36/100
# 24/24 - 1s - loss: 2.9251e-04 - 687ms/epoch - 29ms/step
# Epoch 37/100
# 24/24 - 1s - loss: 2.9968e-04 - 675ms/epoch - 28ms/step
# Epoch 38/100
# 24/24 - 1s - loss: 2.9512e-04 - 702ms/epoch - 29ms/step
# Epoch 39/100
# 24/24 - 1s - loss: 2.9213e-04 - 668ms/epoch - 28ms/step
# Epoch 40/100
# 24/24 - 1s - loss: 2.9652e-04 - 677ms/epoch - 28ms/step
# Epoch 41/100
# 24/24 - 1s - loss: 2.9532e-04 - 690ms/epoch - 29ms/step
# Epoch 42/100
# 24/24 - 1s - loss: 2.8744e-04 - 698ms/epoch - 29ms/step
# Epoch 43/100
# 24/24 - 1s - loss: 2.8827e-04 - 685ms/epoch - 29ms/step
# Epoch 44/100
# 24/24 - 1s - loss: 2.9006e-04 - 684ms/epoch - 29ms/step
# Epoch 45/100
# 24/24 - 1s - loss: 2.8643e-04 - 885ms/epoch - 37ms/step
# Epoch 46/100
# 24/24 - 1s - loss: 2.8712e-04 - 939ms/epoch - 39ms/step
# Epoch 47/100
# 24/24 - 1s - loss: 2.8512e-04 - 754ms/epoch - 31ms/step
# Epoch 48/100
# 24/24 - 1s - loss: 2.8008e-04 - 689ms/epoch - 29ms/step
# Epoch 49/100
# 24/24 - 1s - loss: 2.8853e-04 - 708ms/epoch - 30ms/step
# Epoch 50/100
# 24/24 - 1s - loss: 2.8283e-04 - 698ms/epoch - 29ms/step
# Epoch 51/100
# 24/24 - 1s - loss: 2.8025e-04 - 690ms/epoch - 29ms/step
# Epoch 52/100
# 24/24 - 1s - loss: 2.7944e-04 - 687ms/epoch - 29ms/step
# Epoch 53/100
# 24/24 - 1s - loss: 2.9583e-04 - 695ms/epoch - 29ms/step
# Epoch 54/100
# 24/24 - 1s - loss: 2.8306e-04 - 671ms/epoch - 28ms/step
# Epoch 55/100
# 24/24 - 1s - loss: 2.8243e-04 - 675ms/epoch - 28ms/step
# Epoch 56/100
# 24/24 - 1s - loss: 2.7444e-04 - 664ms/epoch - 28ms/step
# Epoch 57/100
# 24/24 - 1s - loss: 2.8118e-04 - 700ms/epoch - 29ms/step
# Epoch 58/100
# 24/24 - 1s - loss: 2.8017e-04 - 677ms/epoch - 28ms/step
# Epoch 59/100
# 24/24 - 1s - loss: 2.9097e-04 - 687ms/epoch - 29ms/step
# Epoch 60/100
# 24/24 - 1s - loss: 2.8526e-04 - 658ms/epoch - 27ms/step
# Epoch 61/100
# 24/24 - 1s - loss: 2.8138e-04 - 755ms/epoch - 31ms/step
# Epoch 62/100
# 24/24 - 1s - loss: 2.7191e-04 - 940ms/epoch - 39ms/step
# Epoch 63/100
# 24/24 - 1s - loss: 2.6925e-04 - 902ms/epoch - 38ms/step
# Epoch 64/100
# 24/24 - 1s - loss: 2.7719e-04 - 696ms/epoch - 29ms/step
# Epoch 65/100
# 24/24 - 1s - loss: 2.6942e-04 - 709ms/epoch - 30ms/step
# Epoch 66/100
# 24/24 - 1s - loss: 2.7201e-04 - 697ms/epoch - 29ms/step
# Epoch 67/100
# 24/24 - 1s - loss: 2.8201e-04 - 685ms/epoch - 29ms/step
# Epoch 68/100
# 24/24 - 1s - loss: 2.7745e-04 - 686ms/epoch - 29ms/step
# Epoch 69/100
# 24/24 - 1s - loss: 2.6921e-04 - 729ms/epoch - 30ms/step
# Epoch 70/100
# 24/24 - 1s - loss: 2.8987e-04 - 681ms/epoch - 28ms/step
# Epoch 71/100
# 24/24 - 1s - loss: 2.6998e-04 - 691ms/epoch - 29ms/step
# Epoch 72/100
# 24/24 - 1s - loss: 2.7307e-04 - 690ms/epoch - 29ms/step
# Epoch 73/100
# 24/24 - 1s - loss: 2.8236e-04 - 683ms/epoch - 28ms/step
# Epoch 74/100
# 24/24 - 1s - loss: 2.6707e-04 - 651ms/epoch - 27ms/step
# Epoch 75/100
# 24/24 - 1s - loss: 2.6125e-04 - 673ms/epoch - 28ms/step
# Epoch 76/100
# 24/24 - 1s - loss: 2.6743e-04 - 651ms/epoch - 27ms/step
# Epoch 77/100
# 24/24 - 1s - loss: 2.6618e-04 - 682ms/epoch - 28ms/step
# Epoch 78/100
# 24/24 - 1s - loss: 2.8028e-04 - 845ms/epoch - 35ms/step
# Epoch 79/100
# 24/24 - 1s - loss: 2.7175e-04 - 915ms/epoch - 38ms/step
# Epoch 80/100
# 24/24 - 1s - loss: 2.6450e-04 - 819ms/epoch - 34ms/step
# Epoch 81/100
# 24/24 - 1s - loss: 2.5836e-04 - 671ms/epoch - 28ms/step
# Epoch 82/100
# 24/24 - 1s - loss: 2.6724e-04 - 664ms/epoch - 28ms/step
# Epoch 83/100
# 24/24 - 1s - loss: 2.6148e-04 - 720ms/epoch - 30ms/step
# Epoch 84/100
# 24/24 - 1s - loss: 2.6306e-04 - 672ms/epoch - 28ms/step
# Epoch 85/100
# 24/24 - 1s - loss: 2.6389e-04 - 683ms/epoch - 28ms/step
# Epoch 86/100
# 24/24 - 1s - loss: 2.5904e-04 - 704ms/epoch - 29ms/step
# Epoch 87/100
# 24/24 - 1s - loss: 2.6616e-04 - 679ms/epoch - 28ms/step
# Epoch 88/100
# 24/24 - 1s - loss: 2.7349e-04 - 726ms/epoch - 30ms/step
# Epoch 89/100
# 24/24 - 1s - loss: 2.6622e-04 - 701ms/epoch - 29ms/step
# Epoch 90/100
# 24/24 - 1s - loss: 2.6385e-04 - 688ms/epoch - 29ms/step
# Epoch 91/100
# 24/24 - 1s - loss: 2.6221e-04 - 695ms/epoch - 29ms/step
# Epoch 92/100
# 24/24 - 1s - loss: 2.7046e-04 - 692ms/epoch - 29ms/step
# Epoch 93/100
# 24/24 - 1s - loss: 2.8761e-04 - 707ms/epoch - 29ms/step
# Epoch 94/100
# 24/24 - 1s - loss: 2.6776e-04 - 712ms/epoch - 30ms/step
# Epoch 95/100
# 24/24 - 1s - loss: 2.7047e-04 - 951ms/epoch - 40ms/step
# Epoch 96/100
# 24/24 - 1s - loss: 2.7487e-04 - 945ms/epoch - 39ms/step
# Epoch 97/100
# 24/24 - 1s - loss: 2.8618e-04 - 675ms/epoch - 28ms/step
# Epoch 98/100
# 24/24 - 1s - loss: 2.6104e-04 - 681ms/epoch - 28ms/step
# Epoch 99/100
# 24/24 - 1s - loss: 2.6572e-04 - 667ms/epoch - 28ms/step
# Epoch 100/100
# 24/24 - 1s - loss: 2.7118e-04 - 669ms/epoch - 28ms/step

# %% [markdown]
# ## 1-5. 예측

# %%
# 예측
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# model.predict(x_train) 은 학습된 모델을 이용하여 train 데이터에 대한 예측값을 계산한다
# mode.predict(x_test) 은 학습된 모델을 이용하여 test 데이터에 대한 예측값을 계산한다.
# Out:
# 48/48 [==============================] - 1s 8ms/step
# 11/11 [==============================] - 0s 8ms/step

# %% [markdown]
# ## 1-6. 모델 시각화

# %%
import datetime

# 예측 결과 시각화
train_predict = scaler.inverse_transform(train_predict)  # inverse_transform()함수로 원본값을 복원할수있다.
y_train = scaler.inverse_transform(y_train.reshape(-1,1))
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))

# train 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df[look_back:len(train_data)].index, y_train, label='Actual Train Price')
plt.plot(df[look_back:len(train_data)].index, train_predict, label='Predicted Train Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# test 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df[len(train_data)+look_back:].index, y_test, label='Actual Test Price')
plt.plot(df[len(train_data)+look_back:].index, test_predict, label='Predicted Test Price')

# 2031년 1월 1일에 빨간색 세로축을 추가합니다.
target_date = datetime.datetime(2023, 1, 1)
plt.axvline(x=target_date, color='red', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import datetime
from datetime import datetime
# 예측 결과 시각화
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# train_predict와 test_predict 배열에 NaN 값이 포함되어 있는지 확인하기 위해  np.isnan() 함수를 사용
# 만약 NaN 값이 있다면, 이를 np.ma.array() 함수를 사용하여 NaN 값을 마스킹한 배열을 생성한다.
# np.ma.array()에서는 평균값을 구할수있다.(조건이 참일때 평균값을 구해서 NaN값으로 대체한다)

# train_predict와 test_predict 배열의 값을 scaler.inverse_transform() 함수를 사용하여 스케일링된 값을 원래의 값으로 복원합니다.

plt.figure(figsize=(10, 5))

# 2023년 1월 1일에 빨간색 세로축을 추가합니다.
target_date = datetime(2023, 1, 1)
plt.axvline(x=target_date, color='red', linestyle='--')

plt.plot(df[look_back:len(train_data)].index, df[look_back:len(train_data)].values, label='Actual Train Price')
plt.plot(df[len(train_data)+look_back:].index, df[len(train_data)+look_back:].values, label='Actual Test Price')
plt.plot(df[look_back:len(train_data)].index, train_predict, label='Predicted Train Price')
plt.plot(df[len(train_data)+look_back:].index, test_predict, label='Predicted Test Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Bitcoin price prediction for 2023')
plt.legend()
plt.show()

# %% [markdown]
# ## 1-7. R2(결정계수) 을 통한 모델 정확도 계산

# %%
# train 및 test 데이터에 대한 예측값 생성
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# 스케일링 된 값을 다시 원래 값으로 변환
train_predict = scaler.inverse_transform(train_predict)  #inverse_transform() 함수를 이용해 원본값으로 복원가능하다
y_train = scaler.inverse_transform([y_train])
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])


train_r2_score = r2_score(y_train[0], train_predict[:,0])
test_r2_score = r2_score(y_test[0], test_predict[:,0])


# 결과 출력
print("Train R2 Score : ", train_r2_score)  # 99퍼센트에 정확도를 보여준다
print("Test R2 Score : ", test_r2_score)   # 97% 정확도를 보여준다.
# Out:
# 44/44 [==============================] - 1s 12ms/step
# 10/10 [==============================] - 0s 9ms/step
# Train R2 Score :  0.9967646332316978
# Test R2 Score :  0.9876116545839418

# %% [markdown]
# ## 1-7. 모델을 통해 2023년도 예측값 구하기

# %%
model.predict([[2023]])  # 2023년을 예측한 값이다
# Out:
# 1/1 [==============================] - 0s 324ms/step
# array([[6.1882715]], dtype=float32)

# %% [markdown]
# ## 2-1. 2018년~2020년 데이터를 학습하여 2021년 예측값 보여주기

# %% [markdown]
# ### 2-1-1 데이터 불러오기

# %%
# !pip install finance-datareader # FinanceDataReader에서 데이터를 불러오기 위해 FinanceDataReader를 설치하는 과정
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: finance-datareader in /usr/local/lib/python3.10/dist-packages (0.9.50)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.27.1)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)

# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from sklearn.metrics import r2_score

# 데이터 불러오기
start_date_c = "2018-01-01"
end_date_c = "2021-12-31"
ticker_c = "BTC/KRW"
data_c= fdr.DataReader(ticker_c,start_date_c, end_date_c)
df_c = pd.DataFrame(fdr.DataReader(ticker_c, start_date_c, end_date_c)['Close'])

# %%
data_c.head()  # head() 함수를 통해 data_c의 상위 5개만 추출
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-01  15047133.0  15046287.0  14026068.0  14548333.0  14548333.0
# 2018-01-02  14514031.0  16400157.0  13990142.0  15918331.0  15918331.0
# 2018-01-03  15914188.0  16565566.0  15788165.0  16172952.0  16172952.0
# 2018-01-04  16247109.0  16707220.0  15433904.0  16552935.0  16552935.0
# 2018-01-05  16423476.0  18802922.0  16131843.0  18510128.0  18510128.0
#
#                     Volume
# Date
# 2018-01-01  10962700800000
# 2018-01-02  17899344238000
# 2018-01-03  17950689456200
# 2018-01-04  23115024576400
# 2018-01-05  25319034814500

# %%
df_c.head()  # head() 함수를 통해 df_c의 상위 5개만 추출
# Out:
#                  Close
# Date
# 2018-01-01  14548333.0
# 2018-01-02  15918331.0
# 2018-01-03  16172952.0
# 2018-01-04  16552935.0
# 2018-01-05  18510128.0

# %%
len(df_c)  # 전체 데이터의 갯수
# Out:
# 1096

# %% [markdown]
# ### 2-1-2. 데이터 전처리

# %%
# 데이터 전처리
scaler_c = MinMaxScaler()
scaled_data_c = scaler_c.fit_transform(df_c)

# minmaxScaler는 스케일을 조정하는 정규화 함수로, 모든 데이터가 0과 1사이의 값을 갖도록 해주는 함수이다
# 따라서 최댓값은 1로, 최솟값은 0으로 데이터의 범위를 조정해준다. 객체생성함

# %% [markdown]
# ### 2-1-3.  train, test 데이터 생성

# %%
# train, test 데이터 생성
train_size_c = int(len(scaled_data_c) * 0.8) # 전체 데이터셋 중 80%를 학습 데이터셋으로, 20%를 테스트 데이터셋(검증용) 으로 사용하기 위해서 0.8을 곱했다
                                          # 모델 학습 시 과적합을 방지하고 일반화 성능을 높이기 위해 사용된다

train_data_c = scaled_data_c[:train_size_c]
test_data_c = scaled_data_c[train_size_c:]

def create_dataset_c(data_c, look_back_c=60):   # lock_back의 기본값은 60이다  , lock_back에다 데이터 갯수만큼 넣으면 모델학습할때 에러가 나서 기본값이 60을 집어넣었다
    x_c, y_c = [], []                  #  for문에서 얻은 모든 입력 데이터(x_c)와 출력 데이터(y_c)를 리스트에 추가한다
    for i in range(len(data_c)-look_back_c):
        x_c.append(data_c[i:(i+look_back_c), 0])   # i부터 (i+look_back)까지의 데이터를 하나의 입력 데이터 x_c 로 표현한다.
        y_c.append(data_c[i+look_back_c, 0])      # i+look_back의 데이터를 출력 데이터 y_c 로 표현한다.
    return np.array(x_c), np.array(y_c)

look_back_c = 60
x_train_c, y_train_c = create_dataset_c(train_data_c, look_back)
x_test_c, y_test_c = create_dataset_c(test_data_c, look_back)

# create_dataset()는 시계열 데이터를 RNN 모델에 입력으로 사용하기 위해 입력 데이터와 출력 데이터로 분리하는 함수이다.

# %%
x_train_c
# Out:
# array([[0.39120063, 0.440444  , 0.44959613, ..., 0.28481884, 0.2738786 ,
#         0.29414335],
#        [0.440444  , 0.44959613, 0.46325428, ..., 0.2738786 , 0.29414335,
#         0.29812176],
#        [0.44959613, 0.46325428, 0.53360386, ..., 0.29414335, 0.29812176,
#         0.31375874],
#        ...,
#        [0.16696467, 0.16391244, 0.16115775, ..., 0.28845124, 0.2709209 ,
#         0.27776545],
#        [0.16391244, 0.16115775, 0.15029776, ..., 0.2709209 , 0.27776545,
#         0.27895657],
#        [0.16115775, 0.15029776, 0.14037628, ..., 0.27776545, 0.27895657,
#         0.26024032]])

# %%
x_test_c
# Out:
# array([[0.25918738, 0.27695667, 0.29216513, ..., 0.27820958, 0.28205689,
#         0.28017292],
#        [0.27695667, 0.29216513, 0.28612871, ..., 0.28205689, 0.28017292,
#         0.28622907],
#        [0.29216513, 0.28612871, 0.2976956 , ..., 0.28017292, 0.28622907,
#         0.29604311],
#        ...,
#        [0.42170928, 0.4312885 , 0.42951789, ..., 0.91364073, 0.9074564 ,
#         0.93537032],
#        [0.4312885 , 0.42951789, 0.42023036, ..., 0.9074564 , 0.93537032,
#         0.94289069],
#        [0.42951789, 0.42023036, 0.43555823, ..., 0.93537032, 0.94289069,
#         0.99680529]])

# %%
y_train_c
# Out:
# array([2.98121756e-01, 3.13758742e-01, 3.14845225e-01, 3.16159809e-01,
#        2.80239881e-01, 2.50172446e-01, 2.30593721e-01, 2.25511474e-01,
#        2.07470834e-01, 2.34621152e-01, 2.20276214e-01, 2.20703122e-01,
#        1.84114705e-01, 1.87153493e-01, 1.88827411e-01, 1.72624737e-01,
#        1.84626046e-01, 2.00914411e-01, 2.11270127e-01, 2.09757024e-01,
#        2.07062689e-01, 2.13893365e-01, 2.05661191e-01, 1.98916601e-01,
#        1.85277713e-01, 1.70685516e-01, 1.72291786e-01, 1.41794550e-01,
#        1.30869641e-01, 1.34033119e-01, 1.29280192e-01, 1.37194080e-01,
#        1.50671381e-01, 1.28781970e-01, 1.28172897e-01, 1.23448223e-01,
#        1.34013475e-01, 1.38533466e-01, 1.28399867e-01, 1.29516021e-01,
#        1.35187105e-01, 1.71684475e-01, 1.72146860e-01, 1.75621290e-01,
#        1.88813536e-01, 1.78046619e-01, 1.71079068e-01, 1.80500417e-01,
#        1.86162442e-01, 2.08517886e-01, 2.10431443e-01, 2.07264191e-01,
#        2.15031428e-01, 2.43552474e-01, 2.12034155e-01, 2.27474311e-01,
#        2.12861122e-01, 2.26719341e-01, 2.29649757e-01, 2.23431281e-01,
                                                  # lock_back=이전 데이터의 갯수만큼 비트코인 가격을 입력으로 받아들이고, 각각의 데이터가 1차원인 것을 의미합니다.

model_c.add(Dense(1))   # Dense 는 완전 연결 레이어(층)를 의미한다. 1은 출력의 차원을 의미
model_c.compile(loss='mean_squared_error', optimizer='adam')    # compile() 함수를 이용하여 모델을 컴파일합니다
                                                             # loss는 손실 함수를 의미한다.
                                                             # mean_squared_error(MSE) 는 전체 에러를 표현하기 위해서 사용하는 식이고 오차의 제곱에 대해 평균을 취한 것이다.(수치가 작을 수록 원본과의 오차가 적은 것이다)
                                                             # optimizer는  최적화 알고리즘을 정의하는 부분이다. adam(아담) 은 모멘텀+ AdaGrad(아다그라드) 을 합친 것이다

# 완전 연결 레이어 : 한 레이어의 모든 뉴런이 그 다음 레이어의 모든 뉴런과 연결된 상태이다.

# 모멘텀 : 기울기 방향으로 힘을 받아 물체가 가속된다는 물리법칙을 적용한것이다.
# AdaGrad : 학습을 진행하면서 학습률을 점차 줄여가는 방법이다.

# %% [markdown]
# ### 2-1-5. 모델 학습

# %%
# 모델 학습
model_c.fit(x_train_c, y_train_c, epochs=100, batch_size=64, verbose=2)

# x_train_c : 학습데이터의 입력값   , y_train_c : 학습데이터의 출력값이다.

# 에포크 : 훈련 데이터셋에 포함된 모든 데이터들이 한 번씩 모델을 통과한 횟수 또는 전체 학습 데이터셋에 대한 반복 횟수이다
# 에포크가 높을수록 더 많은 반복 학습을 수행하게 되므로 모델이 더 많은 학습을 하게 되어 일반적으로 더 좋은 성능을 낼 수 있습니다

# batch_size(배치크기) : 학습을 수행할 때, 몇 개의 데이터를 한 번에 처리할지를 지정한다, 일반적으로 32,64, 128 숫자를 사용한다

# verbose : 학습 과정 중 출력되는 문구를 설정합니다. 0일 경우 출력하지 않으며, 1일 경우 학습 진행 상황을 출력하고, 2일 경우 학습 결과만 출력한다
# Out:
# Epoch 1/100
# 18/18 - 3s - loss: 0.0121 - 3s/epoch - 159ms/step
# Epoch 2/100
# 18/18 - 1s - loss: 0.0015 - 667ms/epoch - 37ms/step
# Epoch 3/100
# 18/18 - 1s - loss: 4.0255e-04 - 513ms/epoch - 29ms/step
# Epoch 4/100
# 18/18 - 1s - loss: 2.0150e-04 - 521ms/epoch - 29ms/step
# Epoch 5/100
# 18/18 - 1s - loss: 1.7133e-04 - 519ms/epoch - 29ms/step
# Epoch 6/100
# 18/18 - 1s - loss: 1.7138e-04 - 546ms/epoch - 30ms/step
# Epoch 7/100
# 18/18 - 1s - loss: 1.6723e-04 - 519ms/epoch - 29ms/step
# Epoch 8/100
# 18/18 - 1s - loss: 1.6353e-04 - 533ms/epoch - 30ms/step
# Epoch 9/100
# 18/18 - 1s - loss: 1.6322e-04 - 537ms/epoch - 30ms/step
# Epoch 10/100
# 18/18 - 1s - loss: 1.5776e-04 - 550ms/epoch - 31ms/step
# Epoch 11/100
# 18/18 - 1s - loss: 1.5438e-04 - 525ms/epoch - 29ms/step
# Epoch 12/100
# 18/18 - 1s - loss: 1.5061e-04 - 533ms/epoch - 30ms/step
# Epoch 13/100
# 18/18 - 1s - loss: 1.4959e-04 - 506ms/epoch - 28ms/step
# Epoch 14/100
# 18/18 - 1s - loss: 1.4611e-04 - 515ms/epoch - 29ms/step
# Epoch 15/100
# 18/18 - 1s - loss: 1.4269e-04 - 530ms/epoch - 29ms/step
# Epoch 16/100
# 18/18 - 1s - loss: 1.4262e-04 - 539ms/epoch - 30ms/step
# Epoch 17/100
# 18/18 - 1s - loss: 1.4519e-04 - 910ms/epoch - 51ms/step
# Epoch 18/100
# 18/18 - 1s - loss: 1.3726e-04 - 752ms/epoch - 42ms/step
# Epoch 19/100
# 18/18 - 1s - loss: 1.3539e-04 - 1s/epoch - 70ms/step
# Epoch 20/100
# 18/18 - 1s - loss: 1.3446e-04 - 1s/epoch - 64ms/step
# Epoch 21/100
# 18/18 - 1s - loss: 1.2978e-04 - 674ms/epoch - 37ms/step
# Epoch 22/100
# 18/18 - 1s - loss: 1.2744e-04 - 513ms/epoch - 28ms/step
# Epoch 23/100
# 18/18 - 1s - loss: 1.3010e-04 - 525ms/epoch - 29ms/step
# Epoch 24/100
# 18/18 - 1s - loss: 1.3558e-04 - 528ms/epoch - 29ms/step
# Epoch 25/100
# 18/18 - 1s - loss: 1.2212e-04 - 518ms/epoch - 29ms/step
# Epoch 26/100
# 18/18 - 1s - loss: 1.2572e-04 - 522ms/epoch - 29ms/step
# Epoch 27/100
# 18/18 - 1s - loss: 1.2068e-04 - 526ms/epoch - 29ms/step
# Epoch 28/100
# 18/18 - 1s - loss: 1.2451e-04 - 514ms/epoch - 29ms/step
# Epoch 29/100
# 18/18 - 1s - loss: 1.1837e-04 - 533ms/epoch - 30ms/step
# Epoch 30/100
# 18/18 - 1s - loss: 1.2530e-04 - 519ms/epoch - 29ms/step
# Epoch 31/100
# 18/18 - 1s - loss: 1.1860e-04 - 535ms/epoch - 30ms/step
# Epoch 32/100
# 18/18 - 1s - loss: 1.2227e-04 - 558ms/epoch - 31ms/step
# Epoch 33/100
# 18/18 - 1s - loss: 1.1628e-04 - 541ms/epoch - 30ms/step
# Epoch 34/100
# 18/18 - 1s - loss: 1.1382e-04 - 545ms/epoch - 30ms/step
# Epoch 35/100
# 18/18 - 1s - loss: 1.1415e-04 - 550ms/epoch - 31ms/step
# Epoch 36/100
# 18/18 - 1s - loss: 1.1021e-04 - 539ms/epoch - 30ms/step
# Epoch 37/100
# 18/18 - 1s - loss: 1.1025e-04 - 528ms/epoch - 29ms/step
# Epoch 38/100
# 18/18 - 1s - loss: 1.0979e-04 - 550ms/epoch - 31ms/step
# Epoch 39/100
# 18/18 - 1s - loss: 1.2241e-04 - 530ms/epoch - 29ms/step
# Epoch 40/100
# 18/18 - 1s - loss: 1.0612e-04 - 672ms/epoch - 37ms/step
# Epoch 41/100
# 18/18 - 1s - loss: 1.0730e-04 - 755ms/epoch - 42ms/step
# Epoch 42/100
# 18/18 - 1s - loss: 1.2021e-04 - 752ms/epoch - 42ms/step
# Epoch 43/100
# 18/18 - 1s - loss: 1.0765e-04 - 543ms/epoch - 30ms/step
# Epoch 44/100
# 18/18 - 1s - loss: 9.3484e-05 - 535ms/epoch - 30ms/step
# Epoch 76/100
# 18/18 - 1s - loss: 9.2478e-05 - 512ms/epoch - 28ms/step
# Epoch 77/100
# 18/18 - 1s - loss: 9.2808e-05 - 651ms/epoch - 36ms/step
# Epoch 78/100
# 18/18 - 1s - loss: 8.8060e-05 - 700ms/epoch - 39ms/step
# Epoch 79/100
# 18/18 - 1s - loss: 9.1065e-05 - 726ms/epoch - 40ms/step
# Epoch 80/100
# 18/18 - 1s - loss: 9.1218e-05 - 827ms/epoch - 46ms/step
# Epoch 81/100
# 18/18 - 1s - loss: 8.7251e-05 - 764ms/epoch - 42ms/step
# Epoch 82/100
# 18/18 - 1s - loss: 8.9115e-05 - 1s/epoch - 64ms/step
# Epoch 83/100
# 18/18 - 1s - loss: 1.0534e-04 - 755ms/epoch - 42ms/step
# Epoch 84/100
# 18/18 - 1s - loss: 1.0077e-04 - 504ms/epoch - 28ms/step
# Epoch 85/100
# 18/18 - 1s - loss: 9.3389e-05 - 520ms/epoch - 29ms/step
# Epoch 86/100
# 18/18 - 1s - loss: 9.1407e-05 - 529ms/epoch - 29ms/step
# Epoch 87/100
# 18/18 - 1s - loss: 9.1996e-05 - 537ms/epoch - 30ms/step
# Epoch 88/100
# 18/18 - 1s - loss: 1.0566e-04 - 513ms/epoch - 28ms/step
# Epoch 89/100
# 18/18 - 1s - loss: 8.9632e-05 - 525ms/epoch - 29ms/step
# Epoch 90/100
# 18/18 - 1s - loss: 1.0298e-04 - 564ms/epoch - 31ms/step
# Epoch 91/100
# 18/18 - 1s - loss: 8.8358e-05 - 585ms/epoch - 33ms/step
# Epoch 92/100
# 18/18 - 1s - loss: 8.4528e-05 - 683ms/epoch - 38ms/step
# Epoch 93/100
# 18/18 - 1s - loss: 8.6631e-05 - 711ms/epoch - 39ms/step
# Epoch 94/100
# 18/18 - 1s - loss: 8.7118e-05 - 829ms/epoch - 46ms/step
# Epoch 95/100
# 18/18 - 1s - loss: 8.9604e-05 - 582ms/epoch - 32ms/step
# Epoch 96/100
# 18/18 - 1s - loss: 9.3326e-05 - 513ms/epoch - 28ms/step
# Epoch 97/100
# 18/18 - 1s - loss: 9.4328e-05 - 839ms/epoch - 47ms/step
# Epoch 98/100
# 18/18 - 1s - loss: 8.6523e-05 - 525ms/epoch - 29ms/step
# Epoch 99/100
# 18/18 - 1s - loss: 1.0273e-04 - 684ms/epoch - 38ms/step
# Epoch 100/100
# 18/18 - 1s - loss: 1.0534e-04 - 712ms/epoch - 40ms/step

# %% [markdown]
# ### 2-1-6 모델 예측

# %%
# 예측
train_predict_c = model_c.predict(x_train_c)
test_predict_c = model_c.predict(x_test_c)

# model.predict(x_train_c) 은 학습된 모델을 이용하여 train 데이터에 대한 예측값을 계산한다
# mode.predict(x_test_c) 은 학습된 모델을 이용하여 test 데이터에 대한 예측값을 계산한다.
# Out:
# 35/35 [==============================] - 1s 8ms/step
# 8/8 [==============================] - 0s 11ms/step

# %% [markdown]
# ### 2-1-7 예측결과 시각화

# %%
import matplotlib.pyplot as plt
import datetime

# 예측 결과 시각화
train_predict_c = scaler_c.inverse_transform(train_predict_c)  # inverse_transform()함수로 원본값을 복원할수있다.
y_train_c = scaler_c.inverse_transform(y_train_c.reshape(-1,1))
test_predict_c = scaler_c.inverse_transform(test_predict_c)
y_test_c = scaler_c.inverse_transform(y_test_c.reshape(-1,1))

# train 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df_c[look_back:len(train_data_c)].index, y_train_c, label='Actual Train Price')
plt.plot(df_c[look_back:len(train_data_c)].index, train_predict_c, label='Predicted Train Price')

# 2021년 1월 1일에 빨간색 세로축을 추가합니다.
target_date = datetime.datetime(2021, 1, 1)
plt.axvline(x=target_date, color='red', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# test 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df_c[len(train_data_c)+look_back:].index, y_test_c, label='Actual Test Price')
plt.plot(df_c[len(train_data_c)+look_back:].index, test_predict_c, label='Predicted Test Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ### 2-1-8 모델의 정확도

# %%
train_r2_c = r2_score(y_train_c, train_predict_c)
test_r2_c = r2_score(y_test_c, test_predict_c)

print("Train R2 score:", train_r2_c)  # train 데이터의 결정계수를 나타낸다. 약 98%의 정확도를 나타낸다
print("Test R2 score:", test_r2_c)  # test 데이터의 결정계수를 나타내고, 약 98%의 정확도를 나타낸다
# Out:
# Train R2 score: 0.9805686905934238
# Test R2 score: 0.9737700396392492

# %% [markdown]
# ### 2-1- 9 2021년 예측 값

# %%
model_c.predict([[2021]])  # 2024년에 예측값은 6 이다 . 즉 비트코인은 상승할것이다.
# Out:
# 1/1 [==============================] - 0s 439ms/step
# array([[6.474578]], dtype=float32)

# %% [markdown]
# ## 3. 2019년부터 2021년 데이터 훈련해서 2022년 예측하는 프로그램

# %% [markdown]
# ### 3-1 데이터 불러오기

# %%
# !pip install finance-datareader # FinanceDataReader에서 데이터를 불러오기 위해 FinanceDataReader를 설치하는 과정
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: finance-datareader in /usr/local/lib/python3.10/dist-packages (0.9.50)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.27.1)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)

# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from sklearn.metrics import r2_score

# 데이터 불러오기
start_date_d = "2019-01-01"
end_date_d = "2022-12-31"
ticker_d = "BTC/KRW"
data_d= fdr.DataReader(ticker_d,start_date_d, end_date_d)
df_d = pd.DataFrame(fdr.DataReader(ticker_d, start_date_d, end_date_d)['Close'])

# %%
data_d.head()  # data_d 의 상위 5개만 추출
# Out:
#                   Open       High        Low      Close  Adj Close  \
# Date
# 2019-01-01  4171964.75  4290765.0  4133847.0  4284795.0  4284795.0
# 2019-01-02  4291491.50  4432793.5  4271306.5  4428835.0  4428835.0
# 2019-01-03  4415052.00  4431168.0  4308021.0  4316672.0  4316672.0
# 2019-01-04  4311528.00  4318403.5  4249898.5  4308451.5  4308451.5
# 2019-01-05  4302037.00  4361150.5  4285202.0  4294465.5  4294465.5
#
#                    Volume
# Date
# 2019-01-01  4820662946950
# 2019-01-02  5890487949740
# 2019-01-03  5096891156140
# 2019-01-04  5414399614310
# 2019-01-05  5737885889880

# %%
df_d.head()  # df_d의 상위5개만 추출
# Out:
#                 Close
# Date
# 2019-01-01  4284795.0
# 2019-01-02  4428835.0
# 2019-01-03  4316672.0
# 2019-01-04  4308451.5
# 2019-01-05  4294465.5

# %% [markdown]
# ### 3-1. 데이터 전처리

# %%
# 데이터 전처리
scaler_d = MinMaxScaler()
scaled_data_d = scaler_d.fit_transform(df_d)

# minmaxScaler는 스케일을 조정하는 정규화 함수로, 모든 데이터가 0과 1사이의 값을 갖도록 해주는 함수이다
# 따라서 최댓값은 1로, 최솟값은 0으로 데이터의 범위를 조정해준다. 객체생성함

# %%
scaler_d
# Out:
# MinMaxScaler()

# %%
scaled_data_d
# Out:
# array([[0.00596423],
#        [0.00782726],
#        [0.00637653],
#        ...,
#        [0.6622083 ],
#        [0.67705261],
#        [0.66260507]])

# %% [markdown]
# ### 3-2 train, test 데이터 생성

# %%
# train, test 데이터 생성
train_size_d = int(len(scaled_data_d) * 0.8)
train_data_d = scaled_data_d[:train_size_d]
test_data_d = scaled_data_d[train_size_d:]

def create_dataset_d(data_d, look_back=60):   # lock_back의 기본값은 60이다  , lock_back에다 데이터 갯수마큼 넣으면 모델학습할때 에러가 나서 기본값이 60을 집어넣었다
                                             #look_back은 몇 개의 과거 데이터를 사용할 것인지를 표현하는 것이다
    x_d, y_d = [], []    #  for문에서 얻은 모든 입력 데이터(x_d)와 출력 데이터(y_d)를 리스트에 추가한다
    for i in range(len(data_d)-look_back):
        x_d.append(data_d[i:(i+look_back), 0])   # i부터 (i+look_back)까지의 데이터를 하나의 입력 데이터 x_d 로 표현한다.
        y_d.append(data_d[i+look_back, 0])      # i+look_back의 데이터를 출력 데이터 y_d 로 표현한다.
    return np.array(x_d), np.array(y_d)       # 리스트를 numpy 배열로 변환하여 반환


look_back = 60
x_train_d, y_train_d = create_dataset_d(train_data_d, look_back)
x_test_d, y_test_d = create_dataset_d(test_data_d, look_back)

# %%
print(x_train_d)
len(x_train_d)
# Out:
# [[0.00596423 0.00782726 0.00637653 ... 0.00618687 0.00664541 0.00683718]
#  [0.00782726 0.00637653 0.0062702  ... 0.00664541 0.00683718 0.00690765]
#  [0.00637653 0.0062702  0.0060893  ... 0.00683718 0.00690765 0.00666332]
#  ...
#  [0.72559591 0.70971474 0.7556664  ... 0.54557941 0.49470755 0.49809087]
#  [0.70971474 0.7556664  0.76787669 ... 0.49470755 0.49809087 0.4577427 ]
#  [0.7556664  0.76787669 0.76754273 ... 0.49809087 0.4577427  0.51284588]]
# 816

# %%
print(x_test_d)
len(x_test_d)
# Out:
# [[0.51800091 0.50650618 0.46482869 ... 0.43155907 0.45096583 0.46155936]
#  [0.50650618 0.46482869 0.44924729 ... 0.45096583 0.46155936 0.47732173]
#  [0.46482869 0.44924729 0.46454885 ... 0.46155936 0.47732173 0.5071486 ]
#  ...
#  [0.89079484 0.88213662 0.87968544 ... 0.72962815 0.72778798 0.68223869]
#  [0.88213662 0.87968544 0.91480455 ... 0.72778798 0.68223869 0.6622083 ]
#  [0.87968544 0.91480455 0.91188764 ... 0.68223869 0.6622083  0.67705261]]
# 160

# %%
print(y_train_d)
len(y_train_d)
# Out:
# [0.00690765 0.00666332 0.00547909 0.00735045 0.00750199 0.00792123
#  0.00775705 0.00869078 0.00855688 0.00771449 0.00759081 0.00767182
#  0.00823459 0.00864598 0.00993412 0.00971447 0.00959739 0.01008466
#  0.01006809 0.00937397 0.00964568 0.00981985 0.00974441 0.00871373
                                                  # lock_back=이전 데이터의 갯수만큼 비트코인 가격을 입력으로 받아들이고, 각각의 데이터가 1차원인 것을 의미합니다.

model_d.add(Dense(1))   # Dense 는 완전 연결 레이어(층)를 의미한다. 1은 출력의 차원을 의미
model_d.compile(loss='mean_squared_error', optimizer='adam') # compile() 함수를 이용하여 모델을 컴파일합니다
                                                             # loss는 손실 함수를 의미한다.
                                                             # mean_squared_error(MSE) 는 전체 에러를 표현하기 위해서 사용하는 식이고 오차의 제곱에 대해 평균을 취한 것이다.(수치가 작을 수록 원본과의 오차가 적은 것이다)
                                                             # optimizer는  최적화 알고리즘을 정의하는 부분이다. adam(아담) 은 모멘텀+ AdaGrad(아다그라드) 을 합친 것이다

# 완전 연결 레이어 : 한 레이어의 모든 뉴런이 그 다음 레이어의 모든 뉴런과 연결된 상태이다.
# 모멘텀 : 기울기 방향으로 힘을 받아 물체가 가속된다는 물리법칙을 적용한것이다.
# AdaGrad : 학습을 진행하면서 학습률을 점차 줄여가는 방법이다.

# %% [markdown]
# ### 3-4 모델 학습

# %%
# 모델 학습
model_d.fit(x_train_d, y_train_d, epochs=100, batch_size=64, verbose=2)

# x_train_d : 학습데이터의 입력값   , y_train_d: 학습데이터의 출력값이다.

# 에포크 : 훈련 데이터셋에 포함된 모든 데이터들이 한 번씩 모델을 통과한 횟수 또는 전체 학습 데이터셋에 대한 반복 횟수이다
# 에포크가 높을수록 더 많은 반복 학습을 수행하게 되므로 모델이 더 많은 학습을 하게 되어 일반적으로 더 좋은 성능을 낼 수 있습니다

# batch_size(배치크기) : 학습을 수행할 때, 몇 개의 데이터를 한 번에 처리할지를 지정한다, 일반적으로 32,64, 128 숫자를 사용한다

# verbose : 학습 과정 중 출력되는 문구를 설정합니다. 0일 경우 출력하지 않으며, 1일 경우 학습 진행 상황을 출력하고, 2일 경우 학습 결과만 출력한다
# Out:
# Epoch 1/100
# 18/18 - 2s - loss: 0.0957 - 2s/epoch - 136ms/step
# Epoch 2/100
# 18/18 - 0s - loss: 0.0185 - 498ms/epoch - 28ms/step
# Epoch 3/100
# 18/18 - 1s - loss: 0.0047 - 512ms/epoch - 28ms/step
# Epoch 4/100
# 18/18 - 1s - loss: 9.3351e-04 - 501ms/epoch - 28ms/step
# Epoch 5/100
# 18/18 - 1s - loss: 7.7998e-04 - 501ms/epoch - 28ms/step
# Epoch 6/100
# 18/18 - 1s - loss: 6.9775e-04 - 700ms/epoch - 39ms/step
# Epoch 7/100
# 18/18 - 1s - loss: 6.5384e-04 - 699ms/epoch - 39ms/step
# Epoch 8/100
# 18/18 - 1s - loss: 6.4357e-04 - 926ms/epoch - 51ms/step
# Epoch 9/100
# 18/18 - 1s - loss: 6.1629e-04 - 941ms/epoch - 52ms/step
# Epoch 10/100
# 18/18 - 1s - loss: 6.0093e-04 - 507ms/epoch - 28ms/step
# Epoch 11/100
# 18/18 - 1s - loss: 5.8430e-04 - 510ms/epoch - 28ms/step
# Epoch 12/100
# 18/18 - 1s - loss: 5.7307e-04 - 517ms/epoch - 29ms/step
# Epoch 13/100
# 18/18 - 0s - loss: 3.5978e-04 - 488ms/epoch - 27ms/step
# Epoch 76/100
# 18/18 - 1s - loss: 3.5074e-04 - 505ms/epoch - 28ms/step
# Epoch 77/100
# 18/18 - 0s - loss: 3.4892e-04 - 491ms/epoch - 27ms/step
# Epoch 78/100
# 18/18 - 0s - loss: 3.6397e-04 - 490ms/epoch - 27ms/step
# Epoch 79/100
# 18/18 - 0s - loss: 3.4933e-04 - 485ms/epoch - 27ms/step
# Epoch 80/100
# 18/18 - 1s - loss: 3.6177e-04 - 506ms/epoch - 28ms/step
# Epoch 81/100
# 18/18 - 1s - loss: 3.5033e-04 - 509ms/epoch - 28ms/step
# Epoch 82/100
# 18/18 - 1s - loss: 3.5166e-04 - 504ms/epoch - 28ms/step
# Epoch 83/100
# 18/18 - 0s - loss: 3.4689e-04 - 481ms/epoch - 27ms/step
# Epoch 84/100
# 18/18 - 1s - loss: 3.5297e-04 - 506ms/epoch - 28ms/step
# Epoch 85/100
# 18/18 - 0s - loss: 3.5552e-04 - 499ms/epoch - 28ms/step
# Epoch 86/100
# 18/18 - 1s - loss: 3.5210e-04 - 507ms/epoch - 28ms/step
# Epoch 87/100
# 18/18 - 0s - loss: 3.6293e-04 - 496ms/epoch - 28ms/step
# Epoch 88/100
# 18/18 - 0s - loss: 3.5508e-04 - 497ms/epoch - 28ms/step
# Epoch 89/100
# 18/18 - 1s - loss: 3.4585e-04 - 518ms/epoch - 29ms/step
# Epoch 90/100
# 18/18 - 1s - loss: 3.3922e-04 - 503ms/epoch - 28ms/step
# Epoch 91/100
# 18/18 - 0s - loss: 3.3661e-04 - 499ms/epoch - 28ms/step
# Epoch 92/100
# 18/18 - 1s - loss: 3.6227e-04 - 693ms/epoch - 39ms/step
# Epoch 93/100
# 18/18 - 1s - loss: 3.4040e-04 - 697ms/epoch - 39ms/step
# Epoch 94/100
# 18/18 - 1s - loss: 3.3983e-04 - 674ms/epoch - 37ms/step
# Epoch 95/100
# 18/18 - 1s - loss: 3.3838e-04 - 512ms/epoch - 28ms/step
# Epoch 96/100
# 18/18 - 0s - loss: 3.4083e-04 - 497ms/epoch - 28ms/step
# Epoch 97/100
# 18/18 - 0s - loss: 3.4156e-04 - 498ms/epoch - 28ms/step
# Epoch 98/100
# 18/18 - 1s - loss: 3.3882e-04 - 501ms/epoch - 28ms/step
# Epoch 99/100
# 18/18 - 0s - loss: 3.6460e-04 - 492ms/epoch - 27ms/step
# Epoch 100/100
# 18/18 - 1s - loss: 3.5186e-04 - 504ms/epoch - 28ms/step

# %% [markdown]
# ### 3.5 모델 예측

# %%
# 예측
train_predict_d = model_d.predict(x_train_d)
test_predict_d = model_d.predict(x_test_d)

# model.predict(x_train_d) 은 학습된 모델을 이용하여 train 데이터에 대한 예측값을 계산한다
# mode.predict(x_test_d) 은 학습된 모델을 이용하여 test 데이터에 대한 예측값을 계산한다.
# Out:
# 35/35 [==============================] - 1s 9ms/step
# 8/8 [==============================] - 0s 9ms/step

# %% [markdown]
# ### 3-6. 예측 결과 시각화

# %%
import matplotlib.pyplot as plt
import datetime

# 예측 결과 시각화
train_predict_d = scaler_d.inverse_transform(train_predict_d)   # inverse_transform() 함수로 원본값을 반환가능하다
y_train_d = scaler_d.inverse_transform(y_train_d.reshape(-1,1))
test_predict_d = scaler_d.inverse_transform(test_predict_d)
y_test_d = scaler_d.inverse_transform(y_test_d.reshape(-1,1))


# train 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df_d[look_back:len(train_data_d)].index, y_train_d, label='Actual Train Price')
plt.plot(df_d[look_back:len(train_data_d)].index, train_predict_d, label='Predicted Train Price')

# 2022년 1월 1일에 빨간색 세로축을 추가합니다.
target_date = datetime.datetime(2022, 1, 1)
plt.axvline(x=target_date, color='red', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# test 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df_d[len(train_data_d)+look_back:].index, y_test_d, label='Actual Test Price')
plt.plot(df_d[len(train_data_d)+look_back:].index, test_predict_d, label='Predicted Test Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ### 3-7. 모델의 정확도 평가

# %%
train_r2_d = r2_score(y_train_d, train_predict_d)
test_r2_d = r2_score(y_test_d, test_predict_d)

print("Train R2 score:", train_r2_d)  # train 데이터의 결정계수를 나타낸것이고, 약 99%의 정확도를 나타낸다
print("Test R2 score:", test_r2_d)   # test 데이터의 결정계수를 나타낸것이고, 약 94%의 정확도를 나타낸다
# Out:
# Train R2 score: 0.9956795063912512
# Test R2 score: 0.9399891556103259

# %% [markdown]
# ### 3-8. 모델을 통한 2022년 예측한 값

# %%
print(model_d.predict([[2022]]))  # 2022년에 예측값은 5.3 이다.
# Out:
# 1/1 [==============================] - 0s 442ms/step
# [[5.3332715]]

# %% [markdown]
# ## 4. 2020년 부터 2022년 데이터를 학습한 후 2023년 예측해보는 프로그램

# %% [markdown]
# ### 4-1. 데이터 불러오기

# %%
# !pip install finance-datareader # FinanceDataReader에서 데이터를 불러오기 위해 FinanceDataReader를 설치하는 과정
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: finance-datareader in /usr/local/lib/python3.10/dist-packages (0.9.50)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.27.1)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)

# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from sklearn.metrics import r2_score

# 데이터 불러오기
start_date_e = "2020-01-01"
end_date_e = "2023-12-31"
ticker_e = "BTC/KRW"
data_e= fdr.DataReader(ticker_e,start_date_e, end_date_e)
df_e = pd.DataFrame(fdr.DataReader(ticker_e, start_date_e, end_date_e)['Close'])

# %%
data_e.head()   # data_e 의 상위 5개만 추출
# Out:
#                  Open       High        Low      Close  Adj Close  \
# Date
# 2020-01-01  8308229.5  8376938.5  8287634.5  8315985.5  8315985.5
# 2020-01-02  8318730.5  8335989.5  8026049.5  8084144.5  8084144.5
# 2020-01-03  8082939.5  8638980.0  8022294.0  8563107.0  8563107.0
# 2020-01-04  8563679.0  8659292.0  8521870.0  8639788.0  8639788.0
# 2020-01-05  8639549.0  8795827.0  8628617.0  8641188.0  8641188.0
#
#                     Volume
# Date
# 2020-01-01  21442786101341
# 2020-01-02  24073835152756
# 2020-01-03  32774051275895
# 2020-01-04  21503438108393
# 2020-01-05  22998351377088

# %%
df_e.head()  # df_e의 상위 5개만 추출
# Out:
#                 Close
# Date
# 2020-01-01  8315985.5
# 2020-01-02  8084144.5
# 2020-01-03  8563107.0
# 2020-01-04  8639788.0
# 2020-01-05  8641188.0

# %%
len(df_e)  # 전체 데이터의 갯수
# Out:
# 1096

# %% [markdown]
# ### 4-2. 데이터 전처리

# %%
# 데이터 전처리
scaler_e = MinMaxScaler()
scaled_data_e = scaler_e.fit_transform(df_e)

# minmaxScaler는 스케일을 조정하는 정규화 함수로, 모든 데이터가 0과 1사이의 값을 갖도록 해주는 함수이다
# 따라서 최댓값은 1로, 최솟값은 0으로 데이터의 범위를 조정해준다. 객체생성함

# %% [markdown]
# ### 4-3. trai, test 데이터 생성

# %%
# train, test 데이터 생성
train_size_e = int(len(scaled_data_e) * 0.8)
train_data_e = scaled_data_e[:train_size_e]
test_data_e = scaled_data_e[train_size_e:]

def create_dataset_e(data_e, look_back=60):   # lock_back의 기본값은 60이다  , lock_back에다 데이터 갯수만큼 넣으면 모델학습할때 에러가 나서 기본값이 60을 집어넣었다
                                               # 모델 학습 시 과적합을 방지하고 일반화 성능을 높이기 위해 사용된다

    x_e, y_e = [], []  #  for문에서 얻은 모든 입력 데이터(x_e)와 출력 데이터(y_e)를 리스트에 추가한다

    for i in range(len(data_e)-look_back):
        x_e.append(data_e[i:(i+look_back), 0])     # i부터 (i+look_back)까지의 데이터를 하나의 입력 데이터 x_e 로 표현한다.
        y_e.append(data_e[i+look_back, 0])   # i+look_back의 데이터를 출력 데이터 y_e 로 표현한다.
    return np.array(x_e), np.array(y_e)      # 리스트를 numpy 배열로 변환하여 반환

look_back = 60
x_train_e, y_train_e = create_dataset_e(train_data_e, look_back)
x_test_e, y_test_e = create_dataset_e(test_data_e, look_back)

# create_dataset()는 시계열 데이터를 RNN 모델에 입력으로 사용하기 위해 입력 데이터와 출력 데이터로 분리하는 함수이다.

# %% [markdown]
# ### 4-4. 모델 생성

# %%
# 모델 생성
model_e = Sequential()   # 모델의 객체생성
model_e.add(GRU(50, input_shape=(look_back, 1))) #  50=레이어의 출력 차원, input_shape=입력 데이터의 형태를 정의를 의미한다.
                                                  # lock_back=이전 데이터의 갯수만큼 비트코인 가격을 입력으로 받아들이고, 각각의 데이터가 1차원인 것을 의미합니다.

model_e.add(Dense(1))   # Dense 는 완전 연결 레이어(층)를 의미한다. 1은 출력의 차원을 의미
model_e.compile(loss='mean_squared_error', optimizer='adam')  # compile() 함수를 이용하여 모델을 컴파일합니다
                                                             # loss는 손실 함수를 의미한다.
                                                             # mean_squared_error(MSE) 는 전체 에러를 표현하기 위해서 사용하는 식이고 오차의 제곱에 대해 평균을 취한 것이다.(수치가 작을 수록 원본과의 오차가 적은 것이다)
                                                             # optimizer는  최적화 알고리즘을 정의하는 부분이다. adam(아담) 은 모멘텀+ AdaGrad(아다그라드) 을 합친 것이다

# 완전 연결 레이어 : 한 레이어의 모든 뉴런이 그 다음 레이어의 모든 뉴런과 연결된 상태이다.
# 모멘텀 : 기울기 방향으로 힘을 받아 물체가 가속된다는 물리법칙을 적용한것이다.
# AdaGrad : 학습을 진행하면서 학습률을 점차 줄여가는 방법이다.

# %% [markdown]
# ### 4-5. 모델 학습

# %%
# 모델 학습
model_e.fit(x_train_e, y_train_e, epochs=100, batch_size=64, verbose=2)   # 데이터 갯수가 많으면 에포크는 50~100 사이, 배치사이즈는 32~64 사이로 지정

# 배치사이즈 = 64 는 1096개의 데이터를 64개씩 묶어서 17번의 배치로 학습을 진행하게 됩니다.

# x_train_e : 학습데이터의 입력값   , y_train_e : 학습데이터의 출력값이다.

# 에포크 : 훈련 데이터셋에 포함된 모든 데이터들이 한 번씩 모델을 통과한 횟수 또는 전체 학습 데이터셋에 대한 반복 횟수이다
# 에포크가 높을수록 더 많은 반복 학습을 수행하게 되므로 모델이 더 많은 학습을 하게 되어 일반적으로 더 좋은 성능을 낼 수 있습니다

# batch_size(배치크기) : 학습을 수행할 때, 몇 개의 데이터를 한 번에 처리할지를 지정한다, 일반적으로 32,64, 128 숫자를 사용한다

# verbose : 학습 과정 중 출력되는 문구를 설정합니다. 0일 경우 출력하지 않으며, 1일 경우 학습 진행 상황을 출력하고, 2일 경우 학습 결과만 출력한다
# Out:
# Epoch 1/100
# 15/15 - 3s - loss: 0.0876 - 3s/epoch - 192ms/step
# Epoch 2/100
# 15/15 - 0s - loss: 0.0195 - 442ms/epoch - 29ms/step
# Epoch 3/100
# 15/15 - 0s - loss: 0.0085 - 442ms/epoch - 29ms/step
# Epoch 4/100
# 15/15 - 0s - loss: 0.0038 - 429ms/epoch - 29ms/step
# Epoch 5/100
# 15/15 - 0s - loss: 0.0018 - 429ms/epoch - 29ms/step
# Epoch 6/100
# 15/15 - 0s - loss: 0.0011 - 442ms/epoch - 29ms/step
# Epoch 7/100
# 15/15 - 1s - loss: 9.7288e-04 - 713ms/epoch - 48ms/step
# Epoch 8/100
# 15/15 - 0s - loss: 9.4427e-04 - 446ms/epoch - 30ms/step
# Epoch 9/100
# 15/15 - 0s - loss: 9.0928e-04 - 429ms/epoch - 29ms/step
# Epoch 10/100
# 15/15 - 0s - loss: 8.8961e-04 - 433ms/epoch - 29ms/step
# Epoch 11/100
# 15/15 - 1s - loss: 8.6568e-04 - 723ms/epoch - 48ms/step
# Epoch 12/100
# 15/15 - 1s - loss: 8.4936e-04 - 891ms/epoch - 59ms/step
# Epoch 13/100
# 15/15 - 1s - loss: 8.2576e-04 - 633ms/epoch - 42ms/step
# Epoch 14/100
# 15/15 - 0s - loss: 8.1703e-04 - 452ms/epoch - 30ms/step
# Epoch 15/100
# 15/15 - 0s - loss: 7.9226e-04 - 437ms/epoch - 29ms/step
# Epoch 16/100
# 15/15 - 0s - loss: 7.9281e-04 - 430ms/epoch - 29ms/step
# Epoch 17/100
# 15/15 - 0s - loss: 7.7189e-04 - 447ms/epoch - 30ms/step
# Epoch 18/100
# 15/15 - 0s - loss: 7.5552e-04 - 424ms/epoch - 28ms/step
# Epoch 19/100
# 15/15 - 0s - loss: 7.5507e-04 - 454ms/epoch - 30ms/step
# Epoch 20/100
# 15/15 - 1s - loss: 7.3097e-04 - 589ms/epoch - 39ms/step
# Epoch 21/100
# 15/15 - 1s - loss: 7.0975e-04 - 579ms/epoch - 39ms/step
# Epoch 22/100
# 15/15 - 1s - loss: 7.1454e-04 - 567ms/epoch - 38ms/step
# Epoch 23/100
# 15/15 - 0s - loss: 6.9316e-04 - 489ms/epoch - 33ms/step
# Epoch 24/100
# 15/15 - 0s - loss: 6.8123e-04 - 425ms/epoch - 28ms/step
# Epoch 25/100
# 15/15 - 0s - loss: 6.7390e-04 - 431ms/epoch - 29ms/step
# Epoch 26/100
# 15/15 - 0s - loss: 6.6326e-04 - 413ms/epoch - 28ms/step
# Epoch 27/100
# 15/15 - 0s - loss: 6.5132e-04 - 416ms/epoch - 28ms/step
# Epoch 28/100
# 15/15 - 0s - loss: 6.4107e-04 - 424ms/epoch - 28ms/step
# Epoch 29/100
# 15/15 - 0s - loss: 6.3631e-04 - 423ms/epoch - 28ms/step
# Epoch 30/100
# 15/15 - 0s - loss: 6.3226e-04 - 437ms/epoch - 29ms/step
# Epoch 31/100
# 15/15 - 0s - loss: 6.2204e-04 - 473ms/epoch - 32ms/step
# Epoch 32/100
# 15/15 - 1s - loss: 6.1823e-04 - 566ms/epoch - 38ms/step
# Epoch 33/100
# 15/15 - 0s - loss: 6.2217e-04 - 432ms/epoch - 29ms/step
# Epoch 34/100
# 15/15 - 0s - loss: 6.1336e-04 - 428ms/epoch - 29ms/step
# Epoch 35/100
# 15/15 - 0s - loss: 6.0619e-04 - 427ms/epoch - 28ms/step
# Epoch 36/100
# 15/15 - 1s - loss: 5.9517e-04 - 663ms/epoch - 44ms/step
# Epoch 37/100
# 15/15 - 1s - loss: 5.9808e-04 - 727ms/epoch - 48ms/step
# Epoch 38/100
# 15/15 - 1s - loss: 6.0474e-04 - 740ms/epoch - 49ms/step
# Epoch 39/100
# 15/15 - 1s - loss: 5.8864e-04 - 801ms/epoch - 53ms/step
# Epoch 40/100
# 15/15 - 1s - loss: 5.8297e-04 - 710ms/epoch - 47ms/step
# Epoch 41/100
# 15/15 - 1s - loss: 5.8972e-04 - 509ms/epoch - 34ms/step
# Epoch 42/100
# 15/15 - 1s - loss: 5.8564e-04 - 837ms/epoch - 56ms/step
# Epoch 43/100
# 15/15 - 1s - loss: 5.6575e-04 - 991ms/epoch - 66ms/step
# Epoch 44/100
# 15/15 - 1s - loss: 5.6952e-04 - 955ms/epoch - 64ms/step
# Epoch 45/100
# 15/15 - 1s - loss: 5.7625e-04 - 780ms/epoch - 52ms/step
# Epoch 46/100
# 15/15 - 0s - loss: 5.5353e-04 - 430ms/epoch - 29ms/step
# Epoch 47/100
# 15/15 - 0s - loss: 5.5532e-04 - 435ms/epoch - 29ms/step
# Epoch 48/100
# 15/15 - 0s - loss: 5.5755e-04 - 450ms/epoch - 30ms/step
# Epoch 49/100
# 15/15 - 0s - loss: 5.4829e-04 - 415ms/epoch - 28ms/step
# Epoch 50/100
# 15/15 - 0s - loss: 5.3985e-04 - 432ms/epoch - 29ms/step
# Epoch 51/100
# 15/15 - 0s - loss: 5.4342e-04 - 417ms/epoch - 28ms/step
# Epoch 52/100
# 15/15 - 0s - loss: 5.5360e-04 - 422ms/epoch - 28ms/step
# Epoch 53/100
# 15/15 - 0s - loss: 5.4312e-04 - 426ms/epoch - 28ms/step
# Epoch 54/100
# 15/15 - 0s - loss: 5.6598e-04 - 421ms/epoch - 28ms/step
# Epoch 55/100
# 15/15 - 0s - loss: 5.7262e-04 - 447ms/epoch - 30ms/step
# Epoch 56/100
# 15/15 - 0s - loss: 5.4347e-04 - 435ms/epoch - 29ms/step
# Epoch 57/100
# 15/15 - 0s - loss: 5.3428e-04 - 423ms/epoch - 28ms/step
# Epoch 58/100
# 15/15 - 0s - loss: 5.2332e-04 - 415ms/epoch - 28ms/step
# Epoch 59/100
# 15/15 - 0s - loss: 5.2022e-04 - 431ms/epoch - 29ms/step
# Epoch 60/100
# 15/15 - 0s - loss: 5.2186e-04 - 441ms/epoch - 29ms/step
# Epoch 61/100
# 15/15 - 0s - loss: 5.1574e-04 - 430ms/epoch - 29ms/step
# Epoch 62/100
# 15/15 - 0s - loss: 5.1992e-04 - 424ms/epoch - 28ms/step
# Epoch 63/100
# 15/15 - 0s - loss: 5.1402e-04 - 426ms/epoch - 28ms/step
# Epoch 64/100
# 15/15 - 0s - loss: 5.2302e-04 - 424ms/epoch - 28ms/step
# Epoch 65/100
# 15/15 - 0s - loss: 5.0598e-04 - 415ms/epoch - 28ms/step
# Epoch 66/100
# 15/15 - 1s - loss: 5.1607e-04 - 545ms/epoch - 36ms/step
# Epoch 67/100
# 15/15 - 1s - loss: 5.1470e-04 - 564ms/epoch - 38ms/step
# Epoch 68/100
# 15/15 - 1s - loss: 5.1702e-04 - 580ms/epoch - 39ms/step
# Epoch 69/100
# 15/15 - 1s - loss: 5.0321e-04 - 590ms/epoch - 39ms/step
# Epoch 70/100
# 15/15 - 0s - loss: 5.0477e-04 - 447ms/epoch - 30ms/step
# Epoch 71/100
# 15/15 - 0s - loss: 4.9828e-04 - 430ms/epoch - 29ms/step
# Epoch 72/100
# 15/15 - 0s - loss: 4.9654e-04 - 438ms/epoch - 29ms/step
# Epoch 73/100
# 15/15 - 0s - loss: 5.1221e-04 - 446ms/epoch - 30ms/step
# Epoch 74/100
# 15/15 - 0s - loss: 5.0459e-04 - 430ms/epoch - 29ms/step
# Epoch 75/100
# 15/15 - 0s - loss: 4.9971e-04 - 431ms/epoch - 29ms/step
# Epoch 76/100
# 15/15 - 0s - loss: 5.1767e-04 - 456ms/epoch - 30ms/step
# Epoch 77/100
# 15/15 - 0s - loss: 5.0758e-04 - 445ms/epoch - 30ms/step
# Epoch 78/100
# 15/15 - 0s - loss: 5.0396e-04 - 426ms/epoch - 28ms/step
# Epoch 79/100
# 15/15 - 0s - loss: 5.0013e-04 - 441ms/epoch - 29ms/step
# Epoch 80/100
# 15/15 - 0s - loss: 5.2084e-04 - 417ms/epoch - 28ms/step
# Epoch 81/100
# 15/15 - 0s - loss: 4.9144e-04 - 419ms/epoch - 28ms/step
# Epoch 82/100
# 15/15 - 0s - loss: 4.8744e-04 - 429ms/epoch - 29ms/step
# Epoch 83/100
# 15/15 - 0s - loss: 4.8699e-04 - 428ms/epoch - 29ms/step
# Epoch 84/100
# 15/15 - 0s - loss: 4.8424e-04 - 428ms/epoch - 29ms/step
# Epoch 85/100
# 15/15 - 0s - loss: 4.9161e-04 - 427ms/epoch - 28ms/step
# Epoch 86/100
# 15/15 - 0s - loss: 4.9765e-04 - 404ms/epoch - 27ms/step
# Epoch 87/100
# 15/15 - 0s - loss: 4.9288e-04 - 424ms/epoch - 28ms/step
# Epoch 88/100
# 15/15 - 0s - loss: 5.0088e-04 - 434ms/epoch - 29ms/step
# Epoch 89/100
# 15/15 - 0s - loss: 4.8858e-04 - 438ms/epoch - 29ms/step
# Epoch 90/100
# 15/15 - 0s - loss: 4.8660e-04 - 433ms/epoch - 29ms/step
# Epoch 91/100
# 15/15 - 0s - loss: 4.8673e-04 - 439ms/epoch - 29ms/step
# Epoch 92/100
# 15/15 - 0s - loss: 4.7706e-04 - 494ms/epoch - 33ms/step
# Epoch 93/100
# 15/15 - 1s - loss: 4.7743e-04 - 568ms/epoch - 38ms/step
# Epoch 94/100
# 15/15 - 1s - loss: 4.7855e-04 - 560ms/epoch - 37ms/step
# Epoch 95/100
# 15/15 - 1s - loss: 4.9130e-04 - 563ms/epoch - 38ms/step
# Epoch 96/100
# 15/15 - 0s - loss: 4.8531e-04 - 430ms/epoch - 29ms/step
# Epoch 97/100
# 15/15 - 0s - loss: 4.8874e-04 - 433ms/epoch - 29ms/step
# Epoch 98/100
# 15/15 - 0s - loss: 4.8366e-04 - 437ms/epoch - 29ms/step
# Epoch 99/100
# 15/15 - 0s - loss: 4.8060e-04 - 433ms/epoch - 29ms/step
# Epoch 100/100
# 15/15 - 0s - loss: 4.7053e-04 - 432ms/epoch - 29ms/step

# %% [markdown]
# ### 4-6. 예측

# %%
# 예측
train_predict_e = model_e.predict(x_train_e)
test_predict_e = model_e.predict(x_test_e)

# model.predict(x_train_e) 은 학습된 모델을 이용하여 train 데이터에 대한 예측값을 계산한다
# mode.predict(x_test_e) 은 학습된 모델을 이용하여 test 데이터에 대한 예측값을 계산한다.
# Out:
# 30/30 [==============================] - 1s 8ms/step
# 6/6 [==============================] - 0s 8ms/step

# %% [markdown]
# ### 4.7. 예측결과 시각화

# %%
import matplotlib.pyplot as plt
import datetime

# 예측 결과 시각화
train_predict_e = scaler_e.inverse_transform(train_predict_e)  # inverse_transform() 함수를 이용하여 원본값을 복원할수있다.
y_train_e = scaler_e.inverse_transform(y_train_e.reshape(-1,1))
test_predict_e = scaler_e.inverse_transform(test_predict_e)
y_test_e = scaler_e.inverse_transform(y_test_e.reshape(-1,1))

# train 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df_e[look_back:len(train_data_e)].index, y_train_e, label='Actual Train Price')
plt.plot(df_e[look_back:len(train_data_e)].index, train_predict_e, label='Predicted Train Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# test 데이터 예측 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(df_e[len(train_data_e)+look_back:].index, y_test_e, label='Actual Test Price')
plt.plot(df_e[len(train_data_e)+look_back:].index, test_predict_e, label='Predicted Test Price')

# 2023년 1월 1일에 빨간색 세로축을 추가합니다.
target_date = datetime.datetime(2023, 1, 1)
plt.axvline(x=target_date, color='red', linestyle='--')

plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ### 4-8. 모델의 정확도

# %%
train_r2_e = r2_score(y_train_e, train_predict_e)
test_r2_e = r2_score(y_test_e, test_predict_e)

print("Train R2 score:", train_r2_e)  # train 데이터의 결정계수를 표현한것이고, 약 99%의 정확도를 나타낸다
print("Test R2 score:", test_r2_e)  # test 데이터의 결정계수를 표현한것이고, 약 93%의 정확도를 나타낸다.
# Out:
# Train R2 score: 0.9935387620820773
# Test R2 score: 0.9289069863411193

# %% [markdown]
# ### 4-9. 2023년도 예측값

# %%
print(model_e.predict([[2023]]))  # 2023년에 예측값은 6.3 이다
# Out:
# 1/1 [==============================] - 0s 426ms/step
# [[6.356764]]
